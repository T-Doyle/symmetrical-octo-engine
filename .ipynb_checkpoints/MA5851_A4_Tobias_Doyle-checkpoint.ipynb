# %%
from pyspark import SparkContext
from pyspark.sql.types import *
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, lit
from functools import reduce
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt
from wordcloud import WordCloud 
import pandas as pd
import re
import string

# %%
# Initiate Spark and create SparkSession (windows requirement to start)
import findspark
findspark.init()
from pyspark import SparkContext
sc = SparkContext.getOrCreate()
spark = SparkSession.builder.master('FM_Analysis').appName('comments').getOrCreate()

# %%
# Create schema and import "comments.csv" file from file directory
schema = StructType([
    StructField("topic", StringType(), True),
    StructField("date", StringType(), True),
    StructField("userid", StringType(), True),
    StructField("post", StringType(), True)])

comments_df = spark.read.format("csv").options(header='true', multiline= "true", quote='"', delimiter = ',').schema(schema).option("mode", "PERMISSIVE").option("inferSchema", "True").load("file:////C:/Users/Toby/Documents/Data Science/MA5851 - Data Science Master Class 1/Assessment 4/comments.csv")

# %%
comments_df.show(60)
# Out:
# +--------------------+--------------------+--------------------+--------------------+
# |               topic|                date|              userid|                post|
# +--------------------+--------------------+--------------------+--------------------+
# |type of bearing f...| 2019-08-15T20:53:31|             BFRAN21|this bearing came...|
# |type of bearing f...| 2019-08-18T11:42:18|       DAVE REYNOLDS|Contaminants in t...|
# |type of bearing f...| 2019-08-22T14:57:40|              AZIZ58|bfran21 posted:
# t...|
# |Bearing current d...| 2016-07-08T09:15:25|              ABHI03|Dear Friends,
# We ...|
# |Bearing current d...| 2016-07-11T15:52:54|        WHITE WALKER|would u please po...|
# |Bearing current d...| 2016-08-29T22:29:47|"""CHUCK BLACKETT"""|When ever I have ...|
# |Bearing current d...| 2016-09-01T07:51:11|              DBTCMP|Consider a Conduc...|
# |Bearing current d...| 2016-09-01T11:06:12|              ABHI03|Thank you Chuck. ...|
# |Bearing current d...| 2016-09-01T11:07:30|              ABHI03|      Thaank you..
#  |
# |Bearing current d...| 2016-09-09T18:52:10|"""CHUCK BLACKETT"""|Hi ABHI03,
# Sorry ...|
# |Bearing current d...| 2016-09-20T12:56:56|              ABHI03|    Thansk Chuck..
#  |
# |Bearing current d...| 2016-09-26T18:41:44|          SOUNDHOUND|I'd like to add t...|
# |Bearing current d...| 2016-09-30T15:53:09|       DAVE REYNOLDS|I too would like ...|
# |Bearing current d...| 2016-09-30T17:17:07|          SOUNDHOUND|Good point. We ex...|
# |Bearing current d...| 2019-08-19T18:53:05|SAM THE GROUNDING...|"First time on th...|
# |            In short| don't be afraid ...| then how does th...|                null|
# |I hope this infor...|                null|                null|                null|
# |              Sam P.|                null|                null|                null|
# |www.shaftgroundin...|                null|                null|                null|
# |                   "|                null|                null|                null|
# |Is Bearing having...| 2017-06-01T05:33:44|        TUSHAR000001|Since last one mo...|
# |Is Bearing having...| 2017-06-02T04:10:34|        TUSHAR000001|innner race of NU...|
# |Is Bearing having...| 2017-06-02T16:31:45|             BEATNIK|Yes, that's textb...|
# |Is Bearing having...| 2019-08-19T18:41:43|SAM THE GROUNDING...|"First time on th...|
# |            In short| don't be afraid ...| then how does th...|                null|
# |I hope this infor...|                null|                null|                null|
# |              Sam P.|                null|                null|                null|
# |www.shaftgroundin...|                null|                null|                null|
# |                   "|                null|                null|                null|
# |Reciprocating Com...| 2019-07-12T05:38:31|           PAWANNLNG|We have Reciproca...|
# |Reciprocating Com...| 2019-07-13T11:38:54|       DAVE REYNOLDS|Please provide ad...|
# |Reciprocating Com...| 2019-07-15T09:53:47|              AZIZ58|pawannlng posted:...|
# |Reciprocating Com...| 2019-07-16T03:55:37|            URQUIOLA|It is necesary to...|
# |GEAR FAILURE AT S...| 2019-05-07T04:29:01|         DOMINICH.VO|Dear Experts,
#  t...|
# |GEAR FAILURE AT S...| 2019-05-07T05:19:34|       KISHORE KUMAR|Dear DOMINICH.VO ...|
# |GEAR FAILURE AT S...| 2019-05-07T06:07:44|         DOMINICH.VO|Dear Mr. Kishore ...|
# |GEAR FAILURE AT S...| 2019-05-08T04:55:30|       KISHORE KUMAR|Dear DOMINICH.VO ...|
# |GEAR FAILURE AT S...| 2019-05-11T11:34:25|       DAVE REYNOLDS|https://www.machi...|
# |GEAR FAILURE AT S...| 2019-05-13T03:46:43|         DOMINICH.VO|Thanks Dave for m...|
# |         VFD failure| 2019-04-29T00:48:23|          LUKEBARBER|What are the main...|
# |         VFD failure| 2019-04-29T13:56:50|               BECAR|- inappropriate V...|
# |         VFD failure| 2019-04-30T02:10:49|          LUKEBARBER|Thank you for the...|
# |Complet root caus...| 2019-03-07T12:26:51|           NICKTRUCK|Hi Dear All!
# I re...|
# |Complet root caus...| 2019-03-08T02:23:02|       YOUSUF MASOOD|RCA is used for s...|
# |Complet root caus...| 2019-03-08T06:26:55|           NICKTRUCK|Hi! thanks a lot ...|
# |Complet root caus...| 2019-03-08T06:50:37|           NICKTRUCK|Letâ€™s say that ...|
# |Complet root caus...| 2019-03-14T02:39:42|       YOUSUF MASOOD|Apologies for the...|
# |    Steam Path Audit| 2019-02-27T00:08:57|        ROTATING GUY|Hi,
# Is there anyo...|
# |    Steam Path Audit| 2019-02-27T14:02:48|       DAVE REYNOLDS|https://beta.spir...|
# |    Steam Path Audit| 2019-02-28T05:36:52|        ROTATING GUY|Dave Reynolds pos...|
# |catastrophic failure| 2019-02-19T07:17:54|                PIZO|Hello Professiona...|
# |catastrophic failure| 2019-02-19T08:00:34|       YOUSUF MASOOD|Though more detai...|
# |catastrophic failure| 2019-02-19T09:21:17|                PIZO|Hi,
# more info: Mo...|
# |catastrophic failure| 2019-02-19T12:33:41|               BECAR|Did you measure b...|
# |catastrophic failure| 2019-02-19T14:36:04|                PIZO|hi
# i did not meas...|
# |catastrophic failure| 2019-02-19T15:11:07|               BECAR|You should use so...|
# |Reference for roo...| 2019-01-21T06:56:51|              AZIZ58|Dear all
# Pls furn...|
# |Reference for roo...| 2019-01-28T22:07:53|        JOHN FROM PA|Conceptually,  RC...|
# |Reference for roo...| 2019-01-29T03:25:49|              AZIZ58|John from PA post...|
# |   Broken Gear Shaft| 2019-01-07T10:55:46|              JENISH|Dear Experts,
# Can...|
# +--------------------+--------------------+--------------------+--------------------+
# only showing top 60 rows

# %%
# Keep topics that contain  "Bearing" or "bearing"
comments_df = comments_df.filter((comments_df.topic.contains('Bearing')) | (comments_df.topic.contains('bearing')))
comments_df.show(60)
# Out:
# +--------------------+--------------------+--------------------+--------------------+
# |               topic|                date|              userid|                post|
# +--------------------+--------------------+--------------------+--------------------+
# |type of bearing f...| 2019-08-15T20:53:31|             BFRAN21|this bearing came...|
# |type of bearing f...| 2019-08-18T11:42:18|       DAVE REYNOLDS|Contaminants in t...|
# |type of bearing f...| 2019-08-22T14:57:40|              AZIZ58|bfran21 posted:
# t...|
# |Bearing current d...| 2016-07-08T09:15:25|              ABHI03|Dear Friends,
# We ...|
# |Bearing current d...| 2016-07-11T15:52:54|        WHITE WALKER|would u please po...|
# |Bearing current d...| 2016-08-29T22:29:47|"""CHUCK BLACKETT"""|When ever I have ...|
# |Bearing current d...| 2016-09-01T07:51:11|              DBTCMP|Consider a Conduc...|
# |Bearing current d...| 2016-09-01T11:06:12|              ABHI03|Thank you Chuck. ...|
# |Bearing current d...| 2016-09-01T11:07:30|              ABHI03|      Thaank you..
#  |
# |Bearing current d...| 2016-09-09T18:52:10|"""CHUCK BLACKETT"""|Hi ABHI03,
# Sorry ...|
# |Bearing current d...| 2016-09-20T12:56:56|              ABHI03|    Thansk Chuck..
#  |
# |Bearing current d...| 2016-09-26T18:41:44|          SOUNDHOUND|I'd like to add t...|
# |Bearing current d...| 2016-09-30T15:53:09|       DAVE REYNOLDS|I too would like ...|
# |Bearing current d...| 2016-09-30T17:17:07|          SOUNDHOUND|Good point. We ex...|
# |Bearing current d...| 2019-08-19T18:53:05|SAM THE GROUNDING...|"First time on th...|
# |Is Bearing having...| 2017-06-01T05:33:44|        TUSHAR000001|Since last one mo...|
# |Is Bearing having...| 2017-06-02T04:10:34|        TUSHAR000001|innner race of NU...|
# |Is Bearing having...| 2017-06-02T16:31:45|             BEATNIK|Yes, that's textb...|
# |Is Bearing having...| 2019-08-19T18:41:43|SAM THE GROUNDING...|"First time on th...|
# |Gas Turbine Beari...| 2018-11-22T19:34:29|        RIZWAN AHMAD|The machine is Tu...|
# |Gas Turbine Beari...| 2018-11-22T19:47:05|        RIZWAN AHMAD|The pic of failed...|
# |Gas Turbine Beari...| 2018-11-26T06:35:22|            NGO DINH|I do not have exp...|
# |Gas Turbine Beari...| 2018-11-26T07:38:48|        RIZWAN AHMAD|Ngo Dinh posted:
# ...|
# |Gas Turbine Beari...| 2018-11-26T07:44:50|        RIZWAN AHMAD|The Ventilation F...|
# |Gas Turbine Beari...| 2018-12-03T05:09:14|            NGO DINH|It is possible th...|
# |Gas Turbine Beari...| 2018-12-03T07:10:43|        RIZWAN AHMAD|During inspection...|
# |Gas Turbine Tilte...| 2018-08-31T05:08:05|           PAWANNLNG|We have Siemens S...|
# |Gas Turbine Tilte...| 2018-08-31T08:43:57|       KISHORE KUMAR|Dear sir ,
# its cl...|
# |Gas Turbine Tilte...| 2018-09-04T07:20:58|        ROTATING GUY|pawannlng posted:...|
# |Gas Turbine Tilte...| 2018-09-04T11:11:36|           PAWANNLNG|Dear Sir
# Oil anal...|
# |Gas Turbine Tilte...| 2018-09-05T07:50:34|              SHERUB|Dear Pawan,
# Witho...|
# |Gas Turbine Tilte...| 2018-09-05T10:52:16|           RAMONRUIZ|Dear Pawannlng, t...|
# |3309 A/C3 Bearing...| 2018-08-21T15:35:37|        ZAVERI_SAGAR|Please check out ...|
# |3309 A/C3 Bearing...| 2018-08-31T14:14:15|            JOHNNY 5|The bearing is in...|
# |3309 A/C3 Bearing...| 2018-08-31T18:16:48|        ZAVERI_SAGAR|Johnny 5 posted:
# ...|
# |Repetitive inner ...| 2018-05-02T04:46:29|         VIDYA SAGAR|Hi Friends,
#      ...|
# |Repetitive inner ...| 2018-05-02T04:54:34|        ROTATING GUY|Hi Vidya,
# How man...|
# |Repetitive inner ...| 2018-05-02T05:47:30|         VIDYA SAGAR|Hi RG,
#           ...|
# |Repetitive inner ...| 2018-05-02T06:50:17|        ROTATING GUY|Vidya,
# how much i...|
# |Repetitive inner ...| 2018-05-02T09:40:05|         VIDYA SAGAR|RG,
#        There ...|
# |Repetitive inner ...| 2018-05-07T21:32:47|             SLEDDER|Measure the beari...|
# |Repetitive inner ...| 2018-05-15T05:15:06|        ROTATING GUY|vidya Sagar poste...|
# |I carried out sho...| it uses the ultr...| very sensitive t...|                null|
# |High Vibration on...| 2018-04-03T15:03:27|      AHMAD ALFAKEER|Dear all
# We have...|
# |High Vibration on...| 2018-04-09T17:04:12|      AHMAD ALFAKEER|Ahmad alfakeer po...|
# |High Vibration on...| 2018-04-10T11:51:24|            NGO DINH|First, I think yo...|
# +--------------------+--------------------+--------------------+--------------------+

# %%
# Remove any null values from comments
comments_df = comments_df.filter(comments_df.post != "null")
posts_rdd = comments_df.select("post").rdd.flatMap(lambda x: x)
posts_rdd.collect()
# Out:
# ["this bearing came out of a belt drive toyo pump. vibrations were showing BSF with sidebands of FTF, gSE spectrum shows it the best. I was hesitant to make the call for this reason since it wasn't showing to much in the velocity spectrums. not sure if it was to early to make the call or not? would this be an example of bearing skewing or smearing?",
#  'Contaminants in the lubrication is my 2 cents\nhttps://www.schaeffler.com/rem...g_failures_us_en.pdf\nDave',
#  "bfran21 posted:\nthis bearing came out of a belt drive toyo pump. vibrations were showing BSF with sidebands of FTF, gSE spectrum shows it the best. I was hesitant to make the call for this reason since it wasn't showing to much in the velocity spectrums. not sure if it was to early to make the call or not? would this be an example of bearing skewing or smearing?\nThis sign of smearing \nAccording to iso 15243 resulting by poor lubrication and light load",
#  'Dear Friends,\nWe have one case where for Mill motors in Sugar industry, the bearings are repeatedly failing due to bearing current (Fluting Marks). The NDE side bearing is a insulated bearing though. After last failure incident we have changed the bearings (DE non insulated and NDE insulated). We have also installed Carbon/Grounding brush on DE shaft end out side the end cover. Also the earthing is checked. However again in this season only after operating for 4 months bearings have failed. \nCan you guide me for identifying reason behind and with corrective actions.\nThanks and regards\nAbhijit',
#  'would u please post the spectrum.how current passes to shaft and bearing and how to avoid it.firsttime i seeing this problem.',
#  'When ever I have experienced bearings failing from current, the first thing I do is upgrade to ceramic rolling elements in the bearing if possible. It is a no hassle sure fix in most applications, and usually for a cost not that significantly higher than complete steel bearings. Bonus, the hybrid steel and ceramic bearing will also have a longer running life. I have never had luck with shaft grounding brushes. Do you have photos of the bearing races, are you sure it is current damage?',
#  'Consider a Conductive Grease such as Kluber electric which has graphite in the grease and allows the current go to ground safely http://www.vibescorp.ca/pdf/Kl...ric_BE_44_152-en.pdf\nYou may also find the following interesting.\nhttp://ecmweb.com/motors/diagn...tor-bearing-currents',
#  'Thank you Chuck. We are looking for a solution with current bearings. ',
#  'Thaank you..\n ',
#  'Hi ABHI03,\nSorry for the delay - I was traveling. It is quite clear that the bearing is having an issue with current arcing from that photo. I would go for the grease, or better the ceramic rolling element bearings. The pump OEM that I use to work for switched over to ceramic rolling elements as standard considering the move by the industry to favor VFD solutions. The use of a VFD can increase stray currents and cause problems that otherwise would not have existed. ',
#  'Thansk Chuck..\n ',
#  "I'd like to add that it's important to make sure when insulating both motor bearings that the driven equipment is insulated from motor. Our company had an instance where preventing another $2K motor rebuild caused a $30K gearbox rebuild because coupling was a metal grid and current went to gearbox bearings.",
#  'I too would like to add some additional experience....Motor 450HP 900RPM 480Volt 3 phase with insulated shafts on both ends, intermittent duty, megged over 1000megs between bare shaft and insulating material on both ends, shaft grounding ring, both bearings have oil not grease and still have electrical fluting. The suspected root cause is the cables from the VFD to the motor not having proper shielding. Had over 300 volts from the rotating shaft to ground!\nBest to measure/test to better determine where the fault lies and put a plan in place once the faults have been determined/verified. Could also be inductance from cables lying next to one another in a cable tray, earth ground is weak or broken, rust/dirt between machine and foundation not allowing a good ground to name a few I have ran across in the past\nDave',
#  "Good point. We experienced fluting to varying degrees on 9 75hp Extruder motors. Installed a couple of ground rings and then had a rep from ring manufacturer test our motors and he showed we still had problem due to bad ground. Inspection found some ground lugs weren't tight but after fix we still had shaft voltages so all motors got rings. I check voltage levels every 3 months and shafts have to be cleaned regularly due to dirty environment. 1 motor has ring mounted internally but I worry about grease pushing past bearing onto ring.",
#  '"First time on this blog and I see these postings are a few years old, but here goes it anyway:\nI reviewed the pictures and agree you are experiencing electrically induced bearing failure.  Incidence rates of bearing failure on VFD motors is at least 60% by 2 years and only continues to climb from there.  It is a well-accepted and pervasive problem that particularly plagues operations that run 24/7.  The following information is based on long-term field and lab studies over 30 years.\n1) Capacitive discharge through the bearing is a local event caused by the VFD gated mechanism switching on and off.   VFD brands, altering the carrier frequency, installing induction absorbers on the wiring, shunts, conductive grease, etc. are not a fix for this phenomenon.  A shaft grounding device is the only known way to economically eliminate capacitive discharge through the bearing.\n2)  Circulating currents can be present on larger framed motors and are inherent to the motor.  This is different than capacitive coupling as described above under #1.  Our field research has shown that motors 100-200hp and with rpm <=1200 or motors >=200hp regardless of rpm are susceptible to circulating currents.  Incident rates of circulating currents being present is 25-35% for the motor parameters described above.  Insulated bearings will not take care of circulating currents as the current will find a parallel pathway and take out bearings in connected equipment.  A typical set-up to deal with circulating currents is to either provide shaft grounding on both ends of the motor or use an insulated bearing on the non-drive end and a drive end shaft grounding system to break the current loop.\n3)  Not all shaft grounding devices are equal.  It is certainly confusing with the different available products on the market.   The following are key principals that cannot be ignored while researching shaft grounding products.  Always have these concepts and questions at the forefront of your mind when researching shaft grounding options:\nThe grounding system MUST be a better competitor to the bearing for grounding the voltage/current away from the bearing.  While most shaft grounding systems lower shaft voltages right out of the box, not all shaft grounding systems lower voltages below the threshold to prevent current flow through the dielectric (bearing grease) then onto the bearing.  Moreover, most shaft grounding systems cannot maintain for the long-term voltages below the known threshold.  One major manufacturer of shaft grounding rings (SGRs) was asked the question during a webinar ""how do you know the grounding system is working?"" and their response was if the shaft voltage readings are below 10v',
#  'Since last one month we observed rise in high frequency component at motor NDE brg. of PA Fan motor (NDE has got 2 brgs.  NU230  & 6830 ).Sound from bearing had increased.We are using emerson CSI 2130 .Spectrum showed high frequency component between 1to 20khz  around 26Gse which got reduced after greasing to 15 gse but within 1 day again increased back. Overall vibration increased to 15mm/sec (zero to peak). In peakvue with 2k hz filter , BPFO peaks were visible (peakvue value around 18). When sound increased from NDE brg. even more ,motor was replaced. Now i am posting NDE side NU 230 Inner race photos and DE side NU230 photos also ,please confirm the bearing defect.',
#  'innner race of NU230 Brg. in zoom view.',
#  "Yes, that's textbook fluting.\n There have been many good discussions here about it over the years: https://www.maintenance.org/top...63202347#77420702863",
#  '"First time on this blog and I see these postings are a couple years old, but here goes it anyway:\nI reviewed the pictures and agree you are experiencing electrically induced bearing failure.  Incidence rates of bearing failure on VFD motors is at least 60% by 2 years and only continues to climb from there.  It is a well-accepted and pervasive problem that particularly plagues operations that run 24/7.  The following information is based on long-term field and lab studies over 30 years.\n1) Capacitive discharge through the bearing is a local event caused by the VFD gated mechanism switching on and off.   VFD brands, altering the carrier frequency, installing induction absorbers on the wiring, shunts, conductive grease, etc. are not a fix for this phenomenon.  A shaft grounding device is the only known way to economically eliminate capacitive discharge through the bearing.\n2)  Circulating currents can be present on larger framed motors and are inherent to the motor.  This is different than capacitive coupling as described above under #1.  Our field research has shown that motors 100-200hp and with rpm <=1200 or motors >=200hp regardless of rpm are susceptible to circulating currents.  Incident rates of circulating currents being present is 25-35% for the motor parameters described above.  Insulated bearings will not take care of circulating currents as the current will find a parallel pathway and take out bearings in connected equipment.  A typical set-up to deal with circulating currents is to either provide shaft grounding on both ends of the motor or use an insulated bearing on the non-drive end and a drive end shaft grounding system to break the current loop.\n3)  Not all shaft grounding devices are equal.  It is certainly confusing with the different available products on the market.   The following are key principals that cannot be ignored while researching shaft grounding products.  Always have these concepts and questions at the forefront of your mind when researching shaft grounding options:\nThe grounding system MUST be a better competitor to the bearing for grounding the voltage/current away from the bearing.  While most shaft grounding systems lower shaft voltages right out of the box, not all shaft grounding systems lower voltages below the threshold to prevent current flow through the dielectric (bearing grease) then onto the bearing.  Moreover, most shaft grounding systems cannot maintain for the long-term voltages below the known threshold.  One major manufacturer of shaft grounding rings (SGRs) was asked the question during a webinar ""how do you know the grounding system is working?"" and their response was if the shaft voltage readings are below 10v',
#  'The machine is Turbo Generator , the Gas turbine is GE Frame 1.\nFire incident happened in GT side due to Lube Oil leakage either internal or external not confirmed yet. Upon inspection , the Babbitt material loss found in bearing#3 (see attached crossection ) at LP rotor. Also coke or tar found at LP bucket. All relevant pics and GT crossection dwg attached .\nThe questions are:\n1) whatâ€™s the origin of lube oil leakage external or internal ? Is it split from bearing housing or lube oil supply pipe leakages ?\n2) whatâ€™s the root cause of lube oil leakage ?\n3) Whatâ€™s the root cause of Babbit materials loss at Lower part of Brg#3? Pics attached \n4) how the coke or tar formed at LP buckets ? Pic attached ',
#  'The pic of failed bearing #3 is also attached.',
#  "I do not have experience on frame 1 but I think you should check some information and answer for yourself that:\n1. The leakage oil just happen at Bearing #3 or at all bearings?\n2. Have you checked the oil drain piping for any plug/stuck? \n3. there is buffer air supplied to labyrinth seal, isn't it? if any, have you checked the buffer air lines? \n4. How about oil vapour system?\n5. Have you checked the bearing temp? when is it increased? the same for vibration?\nIf the fire happen in the moment of GT running, i think that the oil leakage happen from internal (if from external, i believe someone seen and announced).\nThe bearing look like running under too high temp. The oil under high temperature (over 200oC) will form coke. ",
#  "Ngo Dinh posted:\nI do not have experience on frame 1 but I think you should check some information and answer for yourself that:\n1. The leakage oil just happen at Bearing #3 or at all bearings?\nTotal 4 bearings, All bearings Checked , only bearing#3 found with Babbitt material lost. other 3 bearings found normal.\n2. Have you checked the oil drain piping for any plug/stuck? \nYes Checked , no obstruction or Plugging observed.\n3. there is buffer air supplied to labyrinth seal, isn't it? if any, have you checked the buffer air lines? \nYes, Seal air has been taken from 10th stage of Axial Compressor, air supply lines have been checked and found normal for required seal air pressure.\n4. How about oil vapour system?\nPlease elaborate further on this??\n5. Have you checked the bearing temp? when is it increased? the same for vibration?\nUnder Review.\nIf the fire happen in the moment of GT running, i think that the oil leakage happen from internal (if from external, i believe someone seen and announced).\nFire smoke has been observed in exhaust duct of GT, soon after GT enclosure was opened and fire was seen, in 1st thought, LO Pump was shutdown and fire was removed, once LO Pump Started again, the fire happened again then again the L.O Pump was shutdown and fire removed. Fire is for sure due to L.O leakage , but still mystery from where the Oil leaked and how the fire caught? and how the L.O penetrated at LP rotor bucket and formed coking/tar since L.O Pressure is lesser than the Turbine Pressure??\nThe bearing look like running under too high temp. The oil under high temperature (over 200oC) will form coke. \nThe bearing#3 damage looks secondary damage due to fire and dry running of LP rotor (since L.O pump was stopped)\nHow the fire happened , still dont know??\n ",
#  'The Ventilation Fan was also tripped due to breakage of its belt which may increase the T of enclosure and which further melt the Babbitt white metal which leads to bearing failure ?? I am not sure, can u recognize from bearing pic, is it melted during running or stationary? or is it melted due to high LO temp??? I am not sure ',
#  'It is possible that the shaft is been hot due to fire and make the babbit overheat like picture.\nYou should take event sequence and see what happen near the event time. Focus to oil system and clearance, i think you will get your answer.',
#  'During inspection, the brass oil seal was found damaged. So, there is a possibility the oil could leak from Brg#4 and got fire, but question is why Bearing#4 which is near to fire location is not melted and how the fire traveled from Brg#4 towards Brg#3 ?  You know its Turbine Section , the pressure at Brg#3 is higher than the pressure at Brg#4',
#  'We have Siemens SGT 300 ( 7.5 MW) Gas turbine Generator.\nDuring starting of this machine heavy vibration observed and machine tripped at 9000 RPM on high vibration ( Vibration tripping set at 90 Microns). More than 15 trial taken in this machine neglecting vibration. On opening this machine cold end bearing found damage. Photographs attached. What is probable reason for this bearing failure??',
#  'Dear sir ,\nits clear that  the bearing has continuous rub , primary suspect on  Lubrication .But we could find the root cause , if we have Vibration Spectrum ,Orbit plots or Shaft center lone data ,Please post if you have any .',
#  'pawannlng posted:\nWe have Siemens SGT 300 ( 7.5 MW) Gas turbine Generator.\nDuring starting of this machine heavy vibration observed and machine tripped at 9000 RPM on high vibration ( Vibration tripping set at 90 Microns). More than 15 trial taken in this machine neglecting vibration. On opening this machine cold end bearing found damage. Photographs attached. What is probable reason for this bearing failure??\nHi Pawannlng,\nWhy it need to neglect the vibration? could you share plot if any like shaft centerline, sequence of orbit and time signal, bode and polar possible.\nWhen is the last time taken oil analysis prior this incident? \nregards,\nRG',
#  'Dear Sir\nOil analysis was done six month back and report was normal. I am attaching only available  vibration plot.\n ',
#  'Dear Pawan,\nWithout referring the diagnostic plots i think its very difficult to pin point the root causes of the failure. For fluid film tilting pad bearings, we need to refer more plots and one plot may not give clear conclusion. My opinion, since i am practicing vibration analyst more into this type of bearings. For hydro machines this type bearings are commonly used.\nSherub',
#  'Dear Pawannlng, the possibles causes are:\n1.- misalignment (external misalignment)\n2.- bearing housing excentricity (internal misalignment)\n3.- low lub oil pressure in bearing or any restriction in lub line.\n4.- over radial load.\n5.- Preload in bearing (internal or external)\nwe can rule out the last possibles causes using technologies that Rotating Guy said (Shaft centerline, sequence of orbit and time signal, bode and polar possible, spectrum, etc).\n ',
#  'Please check out attached bearing failure picture. Bearing failed within 200 Hours after replacement. \nEquipment: centrifugal pump(Flowserev CPX) for water service\nBearing: SKF 3309 C3(DE) and SKF 6309 C3(NDE)\nBearing Failed 3309 C3\nOil Lubricated Bearing VG 68\nRunning RPM: 900-1100  \nAlignment was under range of 0.05mm\nPrevious bearing life was more than 10000 hours\nwhat could be reason for this failure? Axial/Radial load, Dirt in oil, Bearing manufacturing defects ?\nBrief answer is apprenticed\n Note: Its double raw angular contact ball bearing with metal cage. (Cage removed while taking picture) ',
#  'The bearing is indicating excessive axial loading for some reason.  It does not indicate the presence of excessive heat.  Is it possible, the lubricant was not correct or incorrect amount?  But that would indicate excessive heat.  This was not a manufacturing defect anything related to the bearing.  Could the bearing have possibly been cocked on the shaft?  I have seen that once before, where the bearing was not seated correctly against the shoulder of the journal.  Find the reason for axial loading and you will find the problem.',
#  'Johnny 5 posted:\nThe bearing is indicating excessive axial loading for some reason.  It does not indicate the presence of excessive heat.  Is it possible, the lubricant was not correct or incorrect amount?  But that would indicate excessive heat.  This was not a manufacturing defect anything related to the bearing.  Could the bearing have possibly been cocked on the shaft?  I have seen that once before, where the bearing was not seated correctly against the shoulder of the journal.  Find the reason for axial loading and you will find the problem.\nHey Thanks for reply.\nI think your doubt about cocked bearing is absolutely right. Because there was spacer between bearing&housing in axial direction, which was out of position in small portion.(we observed it in disassembly). At that time I thought it occurred due to disassembly. Thank you for clarifying my confusion. ',
#  'Hi Friends,\n          In one of our HT motor we found inner race defect with side bands of 1XRPM in the spectrum and yesterday  we inspected the bearing and found inner race was cracked.But the history of the equipment says it has already two breakdowns with inner race problem.During the first time inner race was having dent and during second time inner race got seized.\nEquipment Details\nMotor RPM:1489\nMotor KW:1600\nNDE bearing:NU 228\nDE bearing:NU 234 + 6234\nApplication:Cement Grinding\n          What could be the cause of repetitive inner race damage ???\nThanks in advance.\n ',
#  'Hi Vidya,\nHow many months before the previous failing of inner race was? do you have any monitoring device or just a scheduled monitoring?\nin my previous experience, we get this inner race failure when bearing fit and clearance was not achieve.\n regards,',
#  'Hi RG,\n          previous failure was 2 years back and we use SPM instrument for condition monitoring.Does fitment and clearance is the cause for three failures??\nAny Problem due to load ???',
#  'Vidya,\nhow much is the amount of impacting before this happen? is there a temperature increase before? after that crack when you ovehaul, did the inner race spun on the shaft?\nregards,',
#  "RG,\n       There is no significant increase in temperature and yes inner race spun on shaft.\ni didn't get what exactly impacts u are asking,whether the load or in TWF??\n ",
#  "Measure the bearing fit on the shaft, maybe it's way over sized.",
#  'vidya Sagar posted:\nHi RG,\n          previous failure was 2 years back and we use SPM instrument for condition monitoring.Does fitment and clearance is the cause for three failures??\nAny Problem due to load ???\nIm just curious that this is sudden failure or the failure developed? i doubt at the data collection since this is not sees that will generate fault.\nregards,',
#  'Dear all \nWe have an issue  high vibration on BRG #2&3 ,  finish the Major Inspection on this unit when we start the unit , at FSNL ( 3000 RPM ) the vibration for BRG # 2&3 stable not exceed (6 mm/s ) , when the unit is loaded the vibration increase on BRG 2&3 Only , at full load the Vibration reach on BRG # ( 9- 13 mm/s fluctuating ) and BRG #3 ( 7- 8.5 mm/s ) , and in the MI inspection we made casing Alignment as recommended from  manufacturer GE because when open the unit we found the BRG # 2 is damage from Upper haif and BRG # 3 is damage on lower haif and there is oval on AFT compressor casing and before open unit the vibration on BRG # 2 reached ( up to 19mm/s ) , all bearing replaced BY new ones and the vibration still , please to advice me to know what is the cause of vibration .\nnote : all vibration on BRG # 4 & 5 are smooth not exceed  (2mm/s )at Full load \nthanks in advance ',
#  'Ahmad alfakeer posted:\nDear all \nWe have an issue  high vibration on BRG #2&3 ,  finish the Major Inspection on this unit when we start the unit , at FSNL ( 3000 RPM ) the vibration for BRG # 2&3 stable not exceed (6 mm/s ) , when the unit is loaded the vibration increase on BRG 2&3 Only , at full load the Vibration reach on BRG # ( 9- 13 mm/s fluctuating ) and BRG #3 ( 7- 8.5 mm/s ) , and in the MI inspection we made casing Alignment as recommended from  manufacturer GE because when open the unit we found the BRG # 2 is damage from Upper haif and BRG # 3 is damage on lower haif and there is oval on AFT compressor casing and before open unit the vibration on BRG # 2 reached ( up to 19mm/s ) , all bearing replaced BY new ones and the vibration still , please to advice me to know what is the cause of vibration .\nnote : all vibration on BRG # 4 & 5 are smooth not exceed  (2mm/s )at Full load \nthanks in advance \nplease to help me ???',
#  'First, I think you should give us some data (APHT trend, waterfall, SCL, orbit... if any)for review and also the arrangement of machine. I do not know where is bearing#2 or 3 and so on. \nYou said that the casing have done bore alignment due to center of bearing housing 2 and 3 is not coincided. How about the alignment result and how about the rotor center position check (done at some hole on casing). how about labyrinth clearance at both side of bearing? how about the phase?']

# %%
lowerCase_sentRDD = posts_rdd.map(lambda x : x.lower())

# %%
# Tokenise to sentences
def sent_TokenizeFunct(x):
    return nltk.sent_tokenize(x)

sentenceTokenizeRDD = lowerCase_sentRDD.map(sent_TokenizeFunct)

sentenceTokenizeRDD.collect()
# Out:
# [['this bearing came out of a belt drive toyo pump.',
#   'vibrations were showing bsf with sidebands of ftf, gse spectrum shows it the best.',
#   "i was hesitant to make the call for this reason since it wasn't showing to much in the velocity spectrums.",
#   'not sure if it was to early to make the call or not?',
#   'would this be an example of bearing skewing or smearing?'],
#  ['contaminants in the lubrication is my 2 cents\nhttps://www.schaeffler.com/rem...g_failures_us_en.pdf\ndave'],
#  ['bfran21 posted:\nthis bearing came out of a belt drive toyo pump.',
#   'vibrations were showing bsf with sidebands of ftf, gse spectrum shows it the best.',
#   "i was hesitant to make the call for this reason since it wasn't showing to much in the velocity spectrums.",
#   'not sure if it was to early to make the call or not?',
#   'would this be an example of bearing skewing or smearing?',
#   'this sign of smearing \naccording to iso 15243 resulting by poor lubrication and light load'],
#  ['dear friends,\nwe have one case where for mill motors in sugar industry, the bearings are repeatedly failing due to bearing current (fluting marks).',
#   'the nde side bearing is a insulated bearing though.',
#   'after last failure incident we have changed the bearings (de non insulated and nde insulated).',
#   'we have also installed carbon/grounding brush on de shaft end out side the end cover.',
#   'also the earthing is checked.',
#   'however again in this season only after operating for 4 months bearings have failed.',
#   'can you guide me for identifying reason behind and with corrective actions.',
#   'thanks and regards\nabhijit'],
#  ['would u please post the spectrum.how current passes to shaft and bearing and how to avoid it.firsttime i seeing this problem.'],
#  ['when ever i have experienced bearings failing from current, the first thing i do is upgrade to ceramic rolling elements in the bearing if possible.',
#   'it is a no hassle sure fix in most applications, and usually for a cost not that significantly higher than complete steel bearings.',
#   'bonus, the hybrid steel and ceramic bearing will also have a longer running life.',
#   'i have never had luck with shaft grounding brushes.',
#   'do you have photos of the bearing races, are you sure it is current damage?'],
#  ['consider a conductive grease such as kluber electric which has graphite in the grease and allows the current go to ground safely http://www.vibescorp.ca/pdf/kl...ric_be_44_152-en.pdf\nyou may also find the following interesting.',
#   'http://ecmweb.com/motors/diagn...tor-bearing-currents'],
#  ['thank you chuck.', 'we are looking for a solution with current bearings.'],
#  ['thaank you..'],
#  ['hi abhi03,\nsorry for the delay - i was traveling.',
#   'it is quite clear that the bearing is having an issue with current arcing from that photo.',
#   'i would go for the grease, or better the ceramic rolling element bearings.',
#   'the pump oem that i use to work for switched over to ceramic rolling elements as standard considering the move by the industry to favor vfd solutions.',
#   'the use of a vfd can increase stray currents and cause problems that otherwise would not have existed.'],
#  ['thansk chuck..'],
#  ["i'd like to add that it's important to make sure when insulating both motor bearings that the driven equipment is insulated from motor.",
#   'our company had an instance where preventing another $2k motor rebuild caused a $30k gearbox rebuild because coupling was a metal grid and current went to gearbox bearings.'],
#  ['i too would like to add some additional experience....motor 450hp 900rpm 480volt 3 phase with insulated shafts on both ends, intermittent duty, megged over 1000megs between bare shaft and insulating material on both ends, shaft grounding ring, both bearings have oil not grease and still have electrical fluting.',
#   'the suspected root cause is the cables from the vfd to the motor not having proper shielding.',
#   'had over 300 volts from the rotating shaft to ground!',
#   'best to measure/test to better determine where the fault lies and put a plan in place once the faults have been determined/verified.',
#   'could also be inductance from cables lying next to one another in a cable tray, earth ground is weak or broken, rust/dirt between machine and foundation not allowing a good ground to name a few i have ran across in the past\ndave'],
#  ['good point.',
#   'we experienced fluting to varying degrees on 9 75hp extruder motors.',
#   'installed a couple of ground rings and then had a rep from ring manufacturer test our motors and he showed we still had problem due to bad ground.',
#   "inspection found some ground lugs weren't tight but after fix we still had shaft voltages so all motors got rings.",
#   'i check voltage levels every 3 months and shafts have to be cleaned regularly due to dirty environment.',
#   '1 motor has ring mounted internally but i worry about grease pushing past bearing onto ring.'],
#  ['"first time on this blog and i see these postings are a few years old, but here goes it anyway:\ni reviewed the pictures and agree you are experiencing electrically induced bearing failure.',
#   'incidence rates of bearing failure on vfd motors is at least 60% by 2 years and only continues to climb from there.',
#   'it is a well-accepted and pervasive problem that particularly plagues operations that run 24/7.',
#   'the following information is based on long-term field and lab studies over 30 years.',
#   '1) capacitive discharge through the bearing is a local event caused by the vfd gated mechanism switching on and off.',
#   'vfd brands, altering the carrier frequency, installing induction absorbers on the wiring, shunts, conductive grease, etc.',
#   'are not a fix for this phenomenon.',
#   'a shaft grounding device is the only known way to economically eliminate capacitive discharge through the bearing.',
#   '2)  circulating currents can be present on larger framed motors and are inherent to the motor.',
#   'this is different than capacitive coupling as described above under #1.  our field research has shown that motors 100-200hp and with rpm <=1200 or motors >=200hp regardless of rpm are susceptible to circulating currents.',
#   'incident rates of circulating currents being present is 25-35% for the motor parameters described above.',
#   'insulated bearings will not take care of circulating currents as the current will find a parallel pathway and take out bearings in connected equipment.',
#   'a typical set-up to deal with circulating currents is to either provide shaft grounding on both ends of the motor or use an insulated bearing on the non-drive end and a drive end shaft grounding system to break the current loop.',
#   '3)  not all shaft grounding devices are equal.',
#   'it is certainly confusing with the different available products on the market.',
#   'the following are key principals that cannot be ignored while researching shaft grounding products.',
#   'always have these concepts and questions at the forefront of your mind when researching shaft grounding options:\nthe grounding system must be a better competitor to the bearing for grounding the voltage/current away from the bearing.',
#   'while most shaft grounding systems lower shaft voltages right out of the box, not all shaft grounding systems lower voltages below the threshold to prevent current flow through the dielectric (bearing grease) then onto the bearing.',
#   'moreover, most shaft grounding systems cannot maintain for the long-term voltages below the known threshold.',
#   'one major manufacturer of shaft grounding rings (sgrs) was asked the question during a webinar ""how do you know the grounding system is working?""',
#   'and their response was if the shaft voltage readings are below 10v'],
#  ['since last one month we observed rise in high frequency component at motor nde brg.',
#   'of pa fan motor (nde has got 2 brgs.',
#   'nu230  & 6830 ).sound from bearing had increased.we are using emerson csi 2130 .spectrum showed high frequency component between 1to 20khz  around 26gse which got reduced after greasing to 15 gse but within 1 day again increased back.',
#   'overall vibration increased to 15mm/sec (zero to peak).',
#   'in peakvue with 2k hz filter , bpfo peaks were visible (peakvue value around 18).',
#   'when sound increased from nde brg.',
#   'even more ,motor was replaced.',
#   'now i am posting nde side nu 230 inner race photos and de side nu230 photos also ,please confirm the bearing defect.'],
#  ['innner race of nu230 brg.', 'in zoom view.'],
#  ["yes, that's textbook fluting.",
#   'there have been many good discussions here about it over the years: https://www.maintenance.org/top...63202347#77420702863'],
#  ['"first time on this blog and i see these postings are a couple years old, but here goes it anyway:\ni reviewed the pictures and agree you are experiencing electrically induced bearing failure.',
#   'incidence rates of bearing failure on vfd motors is at least 60% by 2 years and only continues to climb from there.',
#   'it is a well-accepted and pervasive problem that particularly plagues operations that run 24/7.',
#   'the following information is based on long-term field and lab studies over 30 years.',
#   '1) capacitive discharge through the bearing is a local event caused by the vfd gated mechanism switching on and off.',
#   'vfd brands, altering the carrier frequency, installing induction absorbers on the wiring, shunts, conductive grease, etc.',
#   'are not a fix for this phenomenon.',
#   'a shaft grounding device is the only known way to economically eliminate capacitive discharge through the bearing.',
#   '2)  circulating currents can be present on larger framed motors and are inherent to the motor.',
#   'this is different than capacitive coupling as described above under #1.  our field research has shown that motors 100-200hp and with rpm <=1200 or motors >=200hp regardless of rpm are susceptible to circulating currents.',
#   'incident rates of circulating currents being present is 25-35% for the motor parameters described above.',
#   'insulated bearings will not take care of circulating currents as the current will find a parallel pathway and take out bearings in connected equipment.',
#   'a typical set-up to deal with circulating currents is to either provide shaft grounding on both ends of the motor or use an insulated bearing on the non-drive end and a drive end shaft grounding system to break the current loop.',
#   '3)  not all shaft grounding devices are equal.',
#   'it is certainly confusing with the different available products on the market.',
#   'the following are key principals that cannot be ignored while researching shaft grounding products.',
#   'always have these concepts and questions at the forefront of your mind when researching shaft grounding options:\nthe grounding system must be a better competitor to the bearing for grounding the voltage/current away from the bearing.',
#   'while most shaft grounding systems lower shaft voltages right out of the box, not all shaft grounding systems lower voltages below the threshold to prevent current flow through the dielectric (bearing grease) then onto the bearing.',
#   'moreover, most shaft grounding systems cannot maintain for the long-term voltages below the known threshold.',
#   'one major manufacturer of shaft grounding rings (sgrs) was asked the question during a webinar ""how do you know the grounding system is working?""',
#   'and their response was if the shaft voltage readings are below 10v'],
#  ['the machine is turbo generator , the gas turbine is ge frame 1.\nfire incident happened in gt side due to lube oil leakage either internal or external not confirmed yet.',
#   'upon inspection , the babbitt material loss found in bearing#3 (see attached crossection ) at lp rotor.',
#   'also coke or tar found at lp bucket.',
#   'all relevant pics and gt crossection dwg attached .',
#   'the questions are:\n1) whatâ€™s the origin of lube oil leakage external or internal ?',
#   'is it split from bearing housing or lube oil supply pipe leakages ?',
#   '2) whatâ€™s the root cause of lube oil leakage ?',
#   '3) whatâ€™s the root cause of babbit materials loss at lower part of brg#3?',
#   'pics attached \n4) how the coke or tar formed at lp buckets ?',
#   'pic attached'],
#  ['the pic of failed bearing #3 is also attached.'],
#  ['i do not have experience on frame 1 but i think you should check some information and answer for yourself that:\n1. the leakage oil just happen at bearing #3 or at all bearings?',
#   '2. have you checked the oil drain piping for any plug/stuck?',
#   "3. there is buffer air supplied to labyrinth seal, isn't it?",
#   'if any, have you checked the buffer air lines?',
#   '4. how about oil vapour system?',
#   '5. have you checked the bearing temp?',
#   'when is it increased?',
#   'the same for vibration?',
#   'if the fire happen in the moment of gt running, i think that the oil leakage happen from internal (if from external, i believe someone seen and announced).',
#   'the bearing look like running under too high temp.',
#   'the oil under high temperature (over 200oc) will form coke.'],
#  ['ngo dinh posted:\ni do not have experience on frame 1 but i think you should check some information and answer for yourself that:\n1. the leakage oil just happen at bearing #3 or at all bearings?',
#   'total 4 bearings, all bearings checked , only bearing#3 found with babbitt material lost.',
#   'other 3 bearings found normal.',
#   '2. have you checked the oil drain piping for any plug/stuck?',
#   'yes checked , no obstruction or plugging observed.',
#   "3. there is buffer air supplied to labyrinth seal, isn't it?",
#   'if any, have you checked the buffer air lines?',
#   'yes, seal air has been taken from 10th stage of axial compressor, air supply lines have been checked and found normal for required seal air pressure.',
#   '4. how about oil vapour system?',
#   'please elaborate further on this??',
#   '5. have you checked the bearing temp?',
#   'when is it increased?',
#   'the same for vibration?',
#   'under review.',
#   'if the fire happen in the moment of gt running, i think that the oil leakage happen from internal (if from external, i believe someone seen and announced).',
#   'fire smoke has been observed in exhaust duct of gt, soon after gt enclosure was opened and fire was seen, in 1st thought, lo pump was shutdown and fire was removed, once lo pump started again, the fire happened again then again the l.o pump was shutdown and fire removed.',
#   'fire is for sure due to l.o leakage , but still mystery from where the oil leaked and how the fire caught?',
#   'and how the l.o penetrated at lp rotor bucket and formed coking/tar since l.o pressure is lesser than the turbine pressure??',
#   'the bearing look like running under too high temp.',
#   'the oil under high temperature (over 200oc) will form coke.',
#   'the bearing#3 damage looks secondary damage due to fire and dry running of lp rotor (since l.o pump was stopped)\nhow the fire happened , still dont know?',
#   '?'],
#  ['the ventilation fan was also tripped due to breakage of its belt which may increase the t of enclosure and which further melt the babbitt white metal which leads to bearing failure ??',
#   'i am not sure, can u recognize from bearing pic, is it melted during running or stationary?',
#   'or is it melted due to high lo temp???',
#   'i am not sure'],
#  ['it is possible that the shaft is been hot due to fire and make the babbit overheat like picture.',
#   'you should take event sequence and see what happen near the event time.',
#   'focus to oil system and clearance, i think you will get your answer.'],
#  ['during inspection, the brass oil seal was found damaged.',
#   'so, there is a possibility the oil could leak from brg#4 and got fire, but question is why bearing#4 which is near to fire location is not melted and how the fire traveled from brg#4 towards brg#3 ?',
#   'you know its turbine section , the pressure at brg#3 is higher than the pressure at brg#4'],
#  ['we have siemens sgt 300 ( 7.5 mw) gas turbine generator.',
#   'during starting of this machine heavy vibration observed and machine tripped at 9000 rpm on high vibration ( vibration tripping set at 90 microns).',
#   'more than 15 trial taken in this machine neglecting vibration.',
#   'on opening this machine cold end bearing found damage.',
#   'photographs attached.',
#   'what is probable reason for this bearing failure?',
#   '?'],
#  ['dear sir ,\nits clear that  the bearing has continuous rub , primary suspect on  lubrication .but we could find the root cause , if we have vibration spectrum ,orbit plots or shaft center lone data ,please post if you have any .'],
#  ['pawannlng posted:\nwe have siemens sgt 300 ( 7.5 mw) gas turbine generator.',
#   'during starting of this machine heavy vibration observed and machine tripped at 9000 rpm on high vibration ( vibration tripping set at 90 microns).',
#   'more than 15 trial taken in this machine neglecting vibration.',
#   'on opening this machine cold end bearing found damage.',
#   'photographs attached.',
#   'what is probable reason for this bearing failure??',
#   'hi pawannlng,\nwhy it need to neglect the vibration?',
#   'could you share plot if any like shaft centerline, sequence of orbit and time signal, bode and polar possible.',
#   'when is the last time taken oil analysis prior this incident?',
#   'regards,\nrg'],
#  ['dear sir\noil analysis was done six month back and report was normal.',
#   'i am attaching only available  vibration plot.'],
#  ['dear pawan,\nwithout referring the diagnostic plots i think its very difficult to pin point the root causes of the failure.',
#   'for fluid film tilting pad bearings, we need to refer more plots and one plot may not give clear conclusion.',
#   'my opinion, since i am practicing vibration analyst more into this type of bearings.',
#   'for hydro machines this type bearings are commonly used.',
#   'sherub'],
#  ['dear pawannlng, the possibles causes are:\n1.- misalignment (external misalignment)\n2.- bearing housing excentricity (internal misalignment)\n3.- low lub oil pressure in bearing or any restriction in lub line.',
#   '4.- over radial load.',
#   '5.- preload in bearing (internal or external)\nwe can rule out the last possibles causes using technologies that rotating guy said (shaft centerline, sequence of orbit and time signal, bode and polar possible, spectrum, etc).'],
#  ['please check out attached bearing failure picture.',
#   'bearing failed within 200 hours after replacement.',
#   'equipment: centrifugal pump(flowserev cpx) for water service\nbearing: skf 3309 c3(de) and skf 6309 c3(nde)\nbearing failed 3309 c3\noil lubricated bearing vg 68\nrunning rpm: 900-1100  \nalignment was under range of 0.05mm\nprevious bearing life was more than 10000 hours\nwhat could be reason for this failure?',
#   'axial/radial load, dirt in oil, bearing manufacturing defects ?',
#   'brief answer is apprenticed\n note: its double raw angular contact ball bearing with metal cage.',
#   '(cage removed while taking picture)'],
#  ['the bearing is indicating excessive axial loading for some reason.',
#   'it does not indicate the presence of excessive heat.',
#   'is it possible, the lubricant was not correct or incorrect amount?',
#   'but that would indicate excessive heat.',
#   'this was not a manufacturing defect anything related to the bearing.',
#   'could the bearing have possibly been cocked on the shaft?',
#   'i have seen that once before, where the bearing was not seated correctly against the shoulder of the journal.',
#   'find the reason for axial loading and you will find the problem.'],
#  ['johnny 5 posted:\nthe bearing is indicating excessive axial loading for some reason.',
#   'it does not indicate the presence of excessive heat.',
#   'is it possible, the lubricant was not correct or incorrect amount?',
#   'but that would indicate excessive heat.',
#   'this was not a manufacturing defect anything related to the bearing.',
#   'could the bearing have possibly been cocked on the shaft?',
#   'i have seen that once before, where the bearing was not seated correctly against the shoulder of the journal.',
#   'find the reason for axial loading and you will find the problem.',
#   'hey thanks for reply.',
#   'i think your doubt about cocked bearing is absolutely right.',
#   'because there was spacer between bearing&housing in axial direction, which was out of position in small portion.',
#   '(we observed it in disassembly).',
#   'at that time i thought it occurred due to disassembly.',
#   'thank you for clarifying my confusion.'],
#  ['hi friends,\n          in one of our ht motor we found inner race defect with side bands of 1xrpm in the spectrum and yesterday  we inspected the bearing and found inner race was cracked.but the history of the equipment says it has already two breakdowns with inner race problem.during the first time inner race was having dent and during second time inner race got seized.',
#   'equipment details\nmotor rpm:1489\nmotor kw:1600\nnde bearing:nu 228\nde bearing:nu 234 + 6234\napplication:cement grinding\n          what could be the cause of repetitive inner race damage ???',
#   'thanks in advance.'],
#  ['hi vidya,\nhow many months before the previous failing of inner race was?',
#   'do you have any monitoring device or just a scheduled monitoring?',
#   'in my previous experience, we get this inner race failure when bearing fit and clearance was not achieve.',
#   'regards,'],
#  ['hi rg,\n          previous failure was 2 years back and we use spm instrument for condition monitoring.does fitment and clearance is the cause for three failures??',
#   'any problem due to load ??',
#   '?'],
#  ['vidya,\nhow much is the amount of impacting before this happen?',
#   'is there a temperature increase before?',
#   'after that crack when you ovehaul, did the inner race spun on the shaft?',
#   'regards,'],
#  ['rg,\n       there is no significant increase in temperature and yes inner race spun on shaft.',
#   "i didn't get what exactly impacts u are asking,whether the load or in twf?",
#   '?'],
#  ["measure the bearing fit on the shaft, maybe it's way over sized."],
#  ['vidya sagar posted:\nhi rg,\n          previous failure was 2 years back and we use spm instrument for condition monitoring.does fitment and clearance is the cause for three failures??',
#   'any problem due to load ???',
#   'im just curious that this is sudden failure or the failure developed?',
#   'i doubt at the data collection since this is not sees that will generate fault.',
#   'regards,'],
#  ['dear all \nwe have an issue  high vibration on brg #2&3 ,  finish the major inspection on this unit when we start the unit , at fsnl ( 3000 rpm ) the vibration for brg # 2&3 stable not exceed (6 mm/s ) , when the unit is loaded the vibration increase on brg 2&3 only , at full load the vibration reach on brg # ( 9- 13 mm/s fluctuating ) and brg #3 ( 7- 8.5 mm/s ) , and in the mi inspection we made casing alignment as recommended from  manufacturer ge because when open the unit we found the brg # 2 is damage from upper haif and brg # 3 is damage on lower haif and there is oval on aft compressor casing and before open unit the vibration on brg # 2 reached ( up to 19mm/s ) , all bearing replaced by new ones and the vibration still , please to advice me to know what is the cause of vibration .',
#   'note : all vibration on brg # 4 & 5 are smooth not exceed  (2mm/s )at full load \nthanks in advance'],
#  ['ahmad alfakeer posted:\ndear all \nwe have an issue  high vibration on brg #2&3 ,  finish the major inspection on this unit when we start the unit , at fsnl ( 3000 rpm ) the vibration for brg # 2&3 stable not exceed (6 mm/s ) , when the unit is loaded the vibration increase on brg 2&3 only , at full load the vibration reach on brg # ( 9- 13 mm/s fluctuating ) and brg #3 ( 7- 8.5 mm/s ) , and in the mi inspection we made casing alignment as recommended from  manufacturer ge because when open the unit we found the brg # 2 is damage from upper haif and brg # 3 is damage on lower haif and there is oval on aft compressor casing and before open unit the vibration on brg # 2 reached ( up to 19mm/s ) , all bearing replaced by new ones and the vibration still , please to advice me to know what is the cause of vibration .',
#   'note : all vibration on brg # 4 & 5 are smooth not exceed  (2mm/s )at full load \nthanks in advance \nplease to help me ??',
#   '?'],
#  ['first, i think you should give us some data (apht trend, waterfall, scl, orbit... if any)for review and also the arrangement of machine.',
#   'i do not know where is bearing#2 or 3 and so on.',
#   'you said that the casing have done bore alignment due to center of bearing housing 2 and 3 is not coincided.',
#   'how about the alignment result and how about the rotor center position check (done at some hole on casing).',
#   'how about labyrinth clearance at both side of bearing?',
#   'how about the phase?']]

# %%
def word_TokenizeFunct(x):
    splitted = [word for line in x for word in line.split()]
    return splitted

wordTokenizeRDD = sentenceTokenizeRDD.map(word_TokenizeFunct)

wordTokenizeRDD.collect()
# Out:
# [['this',
#   'bearing',
#   'came',
#   'out',
#   'of',
#   'a',
#   'belt',
#   'drive',
#   'toyo',
#   'pump.',
#   'vibrations',
#   'were',
#   'showing',
#   'bsf',
#   'with',
#   'sidebands',
#   'of',
#   'ftf,',
#   'gse',
#   'spectrum',
#   'shows',
#   'it',
#   'the',
#   'best.',
#   'i',
#   'was',
#   'hesitant',
#   'to',
#   'make',
#   'the',
#   'call',
#   'for',
#   'this',
#   'reason',
#   'since',
#   'it',
#   "wasn't",
#   'showing',
#   'to',
#   'much',
#   'in',
#   'the',
#   'velocity',
#   'spectrums.',
#   'not',
#   'sure',
#   'if',
#   'it',
#   'was',
#   'to',
#   'early',
#   'to',
#   'make',
#   'the',
#   'call',
#   'or',
#   'not?',
#   'would',
#   'this',
#   'be',
#   'an',
#   'example',
#   'of',
#   'bearing',
#   'skewing',
#   'or',
#   'smearing?'],
#  ['contaminants',
#   'in',
#   'the',
#   'lubrication',
#   'is',
#   'my',
#   '2',
#   'cents',
#   'https://www.schaeffler.com/rem...g_failures_us_en.pdf',
#   'dave'],
#  ['bfran21',
#   'posted:',
#   'this',
#   'bearing',
#   'came',
#   'out',
#   'of',
#   'a',
#   'belt',
#   'drive',
#   'toyo',
#   'pump.',
#   'vibrations',
#   'were',
#   'showing',
#   'bsf',
#   'with',
#   'sidebands',
#   'of',
#   'ftf,',
#   'gse',
#   'spectrum',
#   'shows',
#   'it',
#   'the',
#   'best.',
#   'i',
#   'was',
#   'hesitant',
#   'to',
#   'make',
#   'the',
#   'call',
#   'for',
#   'this',
#   'reason',
#   'since',
#   'it',
#   "wasn't",
#   'showing',
#   'to',
#   'much',
#   'in',
#   'the',
#   'velocity',
#   'spectrums.',
#   'not',
#   'sure',
#   'if',
#   'it',
#   'was',
#   'to',
#   'early',
#   'to',
#   'make',
#   'the',
#   'call',
#   'or',
#   'not?',
#   'would',
#   'this',
#   'be',
#   'an',
#   'example',
#   'of',
#   'bearing',
#   'skewing',
#   'or',
#   'smearing?',
#   'this',
#   'sign',
#   'of',
#   'smearing',
#   'according',
#   'to',
#   'iso',
#   '15243',
#   'resulting',
#   'by',
#   'poor',
#   'lubrication',
#   'and',
#   'light',
#   'load'],
#  ['dear',
#   'friends,',
#   'we',
#   'have',
#   'one',
#   'case',
#   'where',
#   'for',
#   'mill',
#   'motors',
#   'in',
#   'sugar',
#   'industry,',
#   'the',
#   'bearings',
#   'are',
#   'repeatedly',
#   'failing',
#   'due',
#   'to',
#   'bearing',
#   'current',
#   '(fluting',
#   'marks).',
#   'the',
#   'nde',
#   'side',
#   'bearing',
#   'is',
#   'a',
#   'insulated',
#   'bearing',
#   'though.',
#   'after',
#   'last',
#   'failure',
#   'incident',
#   'we',
#   'have',
#   'changed',
#   'the',
#   'bearings',
#   '(de',
#   'non',
#   'insulated',
#   'and',
#   'nde',
#   'insulated).',
#   'we',
#   'have',
#   'also',
#   'installed',
#   'carbon/grounding',
#   'brush',
#   'on',
#   'de',
#   'shaft',
#   'end',
#   'out',
#   'side',
#   'the',
#   'end',
#   'cover.',
#   'also',
#   'the',
#   'earthing',
#   'is',
#   'checked.',
#   'however',
#   'again',
#   'in',
#   'this',
#   'season',
#   'only',
#   'after',
#   'operating',
#   'for',
#   '4',
#   'months',
#   'bearings',
#   'have',
#   'failed.',
#   'can',
#   'you',
#   'guide',
#   'me',
#   'for',
#   'identifying',
#   'reason',
#   'behind',
#   'and',
#   'with',
#   'corrective',
#   'actions.',
#   'thanks',
#   'and',
#   'regards',
#   'abhijit'],
#  ['would',
#   'u',
#   'please',
#   'post',
#   'the',
#   'spectrum.how',
#   'current',
#   'passes',
#   'to',
#   'shaft',
#   'and',
#   'bearing',
#   'and',
#   'how',
#   'to',
#   'avoid',
#   'it.firsttime',
#   'i',
#   'seeing',
#   'this',
#   'problem.'],
#  ['when',
#   'ever',
#   'i',
#   'have',
#   'experienced',
#   'bearings',
#   'failing',
#   'from',
#   'current,',
#   'the',
#   'first',
#   'thing',
#   'i',
#   'do',
#   'is',
#   'upgrade',
#   'to',
#   'ceramic',
#   'rolling',
#   'elements',
#   'in',
#   'the',
#   'bearing',
#   'if',
#   'possible.',
#   'it',
#   'is',
#   'a',
#   'no',
#   'hassle',
#   'sure',
#   'fix',
#   'in',
#   'most',
#   'applications,',
#   'and',
#   'usually',
#   'for',
#   'a',
#   'cost',
#   'not',
#   'that',
#   'significantly',
#   'higher',
#   'than',
#   'complete',
#   'steel',
#   'bearings.',
#   'bonus,',
#   'the',
#   'hybrid',
#   'steel',
#   'and',
#   'ceramic',
#   'bearing',
#   'will',
#   'also',
#   'have',
#   'a',
#   'longer',
#   'running',
#   'life.',
#   'i',
#   'have',
#   'never',
#   'had',
#   'luck',
#   'with',
#   'shaft',
#   'grounding',
#   'brushes.',
#   'do',
#   'you',
#   'have',
#   'photos',
#   'of',
#   'the',
#   'bearing',
#   'races,',
#   'are',
#   'you',
#   'sure',
#   'it',
#   'is',
#   'current',
#   'damage?'],
#  ['consider',
#   'a',
#   'conductive',
#   'grease',
#   'such',
#   'as',
#   'kluber',
#   'electric',
#   'which',
#   'has',
#   'graphite',
#   'in',
#   'the',
#   'grease',
#   'and',
#   'allows',
#   'the',
#   'current',
#   'go',
#   'to',
#   'ground',
#   'safely',
#   'http://www.vibescorp.ca/pdf/kl...ric_be_44_152-en.pdf',
#   'you',
#   'may',
#   'also',
#   'find',
#   'the',
#   'following',
#   'interesting.',
#   'http://ecmweb.com/motors/diagn...tor-bearing-currents'],
#  ['thank',
#   'you',
#   'chuck.',
#   'we',
#   'are',
#   'looking',
#   'for',
#   'a',
#   'solution',
#   'with',
#   'current',
#   'bearings.'],
#  ['thaank', 'you..'],
#  ['hi',
#   'abhi03,',
#   'sorry',
#   'for',
#   'the',
#   'delay',
#   '-',
#   'i',
#   'was',
#   'traveling.',
#   'it',
#   'is',
#   'quite',
#   'clear',
#   'that',
#   'the',
#   'bearing',
#   'is',
#   'having',
#   'an',
#   'issue',
#   'with',
#   'current',
#   'arcing',
#   'from',
#   'that',
#   'photo.',
#   'i',
#   'would',
#   'go',
#   'for',
#   'the',
#   'grease,',
#   'or',
#   'better',
#   'the',
#   'ceramic',
#   'rolling',
#   'element',
#   'bearings.',
#   'the',
#   'pump',
#   'oem',
#   'that',
#   'i',
#   'use',
#   'to',
#   'work',
#   'for',
#   'switched',
#   'over',
#   'to',
#   'ceramic',
#   'rolling',
#   'elements',
#   'as',
#   'standard',
#   'considering',
#   'the',
#   'move',
#   'by',
#   'the',
#   'industry',
#   'to',
#   'favor',
#   'vfd',
#   'solutions.',
#   'the',
#   'use',
#   'of',
#   'a',
#   'vfd',
#   'can',
#   'increase',
#   'stray',
#   'currents',
#   'and',
#   'cause',
#   'problems',
#   'that',
#   'otherwise',
#   'would',
#   'not',
#   'have',
#   'existed.'],
#  ['thansk', 'chuck..'],
#  ["i'd",
#   'like',
#   'to',
#   'add',
#   'that',
#   "it's",
#   'important',
#   'to',
#   'make',
#   'sure',
#   'when',
#   'insulating',
#   'both',
#   'motor',
#   'bearings',
#   'that',
#   'the',
#   'driven',
#   'equipment',
#   'is',
#   'insulated',
#   'from',
#   'motor.',
#   'our',
#   'company',
#   'had',
#   'an',
#   'instance',
#   'where',
#   'preventing',
#   'another',
#   '$2k',
#   'motor',
#   'rebuild',
#   'caused',
#   'a',
#   '$30k',
#   'gearbox',
#   'rebuild',
#   'because',
#   'coupling',
#   'was',
#   'a',
#   'metal',
#   'grid',
#   'and',
#   'current',
#   'went',
#   'to',
#   'gearbox',
#   'bearings.'],
#  ['i',
#   'too',
#   'would',
#   'like',
#   'to',
#   'add',
#   'some',
#   'additional',
#   'experience....motor',
#   '450hp',
#   '900rpm',
#   '480volt',
#   '3',
#   'phase',
#   'with',
#   'insulated',
#   'shafts',
#   'on',
#   'both',
#   'ends,',
#   'intermittent',
#   'duty,',
#   'megged',
#   'over',
#   '1000megs',
#   'between',
#   'bare',
#   'shaft',
#   'and',
#   'insulating',
#   'material',
#   'on',
#   'both',
#   'ends,',
#   'shaft',
#   'grounding',
#   'ring,',
#   'both',
#   'bearings',
#   'have',
#   'oil',
#   'not',
#   'grease',
#   'and',
#   'still',
#   'have',
#   'electrical',
#   'fluting.',
#   'the',
#   'suspected',
#   'root',
#   'cause',
#   'is',
#   'the',
#   'cables',
#   'from',
#   'the',
#   'vfd',
#   'to',
#   'the',
#   'motor',
#   'not',
#   'having',
#   'proper',
#   'shielding.',
#   'had',
#   'over',
#   '300',
#   'volts',
#   'from',
#   'the',
#   'rotating',
#   'shaft',
#   'to',
#   'ground!',
#   'best',
#   'to',
#   'measure/test',
#   'to',
#   'better',
#   'determine',
#   'where',
#   'the',
#   'fault',
#   'lies',
#   'and',
#   'put',
#   'a',
#   'plan',
#   'in',
#   'place',
#   'once',
#   'the',
#   'faults',
#   'have',
#   'been',
#   'determined/verified.',
#   'could',
#   'also',
#   'be',
#   'inductance',
#   'from',
#   'cables',
#   'lying',
#   'next',
#   'to',
#   'one',
#   'another',
#   'in',
#   'a',
#   'cable',
#   'tray,',
#   'earth',
#   'ground',
#   'is',
#   'weak',
#   'or',
#   'broken,',
#   'rust/dirt',
#   'between',
#   'machine',
#   'and',
#   'foundation',
#   'not',
#   'allowing',
#   'a',
#   'good',
#   'ground',
#   'to',
#   'name',
#   'a',
#   'few',
#   'i',
#   'have',
#   'ran',
#   'across',
#   'in',
#   'the',
#   'past',
#   'dave'],
#  ['good',
#   'point.',
#   'we',
#   'experienced',
#   'fluting',
#   'to',
#   'varying',
#   'degrees',
#   'on',
#   '9',
#   '75hp',
#   'extruder',
#   'motors.',
#   'installed',
#   'a',
#   'couple',
#   'of',
#   'ground',
#   'rings',
#   'and',
#   'then',
#   'had',
#   'a',
#   'rep',
#   'from',
#   'ring',
#   'manufacturer',
#   'test',
#   'our',
#   'motors',
#   'and',
#   'he',
#   'showed',
#   'we',
#   'still',
#   'had',
#   'problem',
#   'due',
#   'to',
#   'bad',
#   'ground.',
#   'inspection',
#   'found',
#   'some',
#   'ground',
#   'lugs',
#   "weren't",
#   'tight',
#   'but',
#   'after',
#   'fix',
#   'we',
#   'still',
#   'had',
#   'shaft',
#   'voltages',
#   'so',
#   'all',
#   'motors',
#   'got',
#   'rings.',
#   'i',
#   'check',
#   'voltage',
#   'levels',
#   'every',
#   '3',
#   'months',
#   'and',
#   'shafts',
#   'have',
#   'to',
#   'be',
#   'cleaned',
#   'regularly',
#   'due',
#   'to',
#   'dirty',
#   'environment.',
#   '1',
#   'motor',
#   'has',
#   'ring',
#   'mounted',
#   'internally',
#   'but',
#   'i',
#   'worry',
#   'about',
#   'grease',
#   'pushing',
#   'past',
#   'bearing',
#   'onto',
#   'ring.'],
#  ['"first',
#   'time',
#   'on',
#   'this',
#   'blog',
#   'and',
#   'i',
#   'see',
#   'these',
#   'postings',
#   'are',
#   'a',
#   'few',
#   'years',
#   'old,',
#   'but',
#   'here',
#   'goes',
#   'it',
#   'anyway:',
#   'i',
#   'reviewed',
#   'the',
#   'pictures',
#   'and',
#   'agree',
#   'you',
#   'are',
#   'experiencing',
#   'electrically',
#   'induced',
#   'bearing',
#   'failure.',
#   'incidence',
#   'rates',
#   'of',
#   'bearing',
#   'failure',
#   'on',
#   'vfd',
#   'motors',
#   'is',
#   'at',
#   'least',
#   '60%',
#   'by',
#   '2',
#   'years',
#   'and',
#   'only',
#   'continues',
#   'to',
#   'climb',
#   'from',
#   'there.',
#   'it',
#   'is',
#   'a',
#   'well-accepted',
#   'and',
#   'pervasive',
#   'problem',
#   'that',
#   'particularly',
#   'plagues',
#   'operations',
#   'that',
#   'run',
#   '24/7.',
#   'the',
#   'following',
#   'information',
#   'is',
#   'based',
#   'on',
#   'long-term',
#   'field',
#   'and',
#   'lab',
#   'studies',
#   'over',
#   '30',
#   'years.',
#   '1)',
#   'capacitive',
#   'discharge',
#   'through',
#   'the',
#   'bearing',
#   'is',
#   'a',
#   'local',
#   'event',
#   'caused',
#   'by',
#   'the',
#   'vfd',
#   'gated',
#   'mechanism',
#   'switching',
#   'on',
#   'and',
#   'off.',
#   'vfd',
#   'brands,',
#   'altering',
#   'the',
#   'carrier',
#   'frequency,',
#   'installing',
#   'induction',
#   'absorbers',
#   'on',
#   'the',
#   'wiring,',
#   'shunts,',
#   'conductive',
#   'grease,',
#   'etc.',
#   'are',
#   'not',
#   'a',
#   'fix',
#   'for',
#   'this',
#   'phenomenon.',
#   'a',
#   'shaft',
#   'grounding',
#   'device',
#   'is',
#   'the',
#   'only',
#   'known',
#   'way',
#   'to',
#   'economically',
#   'eliminate',
#   'capacitive',
#   'discharge',
#   'through',
#   'the',
#   'bearing.',
#   '2)',
#   'circulating',
#   'currents',
#   'can',
#   'be',
#   'present',
#   'on',
#   'larger',
#   'framed',
#   'motors',
#   'and',
#   'are',
#   'inherent',
#   'to',
#   'the',
#   'motor.',
#   'this',
#   'is',
#   'different',
#   'than',
#   'capacitive',
#   'coupling',
#   'as',
#   'described',
#   'above',
#   'under',
#   '#1.',
#   'our',
#   'field',
#   'research',
#   'has',
#   'shown',
#   'that',
#   'motors',
#   '100-200hp',
#   'and',
#   'with',
#   'rpm',
#   '<=1200',
#   'or',
#   'motors',
#   '>=200hp',
#   'regardless',
#   'of',
#   'rpm',
#   'are',
#   'susceptible',
#   'to',
#   'circulating',
#   'currents.',
#   'incident',
#   'rates',
#   'of',
#   'circulating',
#   'currents',
#   'being',
#   'present',
#   'is',
#   '25-35%',
#   'for',
#   'the',
#   'motor',
#   'parameters',
#   'described',
#   'above.',
#   'insulated',
#   'bearings',
#   'will',
#   'not',
#   'take',
#   'care',
#   'of',
#   'circulating',
#   'currents',
#   'as',
#   'the',
#   'current',
#   'will',
#   'find',
#   'a',
#   'parallel',
#   'pathway',
#   'and',
#   'take',
#   'out',
#   'bearings',
#   'in',
#   'connected',
#   'equipment.',
#   'a',
#   'typical',
#   'set-up',
#   'to',
#   'deal',
#   'with',
#   'circulating',
#   'currents',
#   'is',
#   'to',
#   'either',
#   'provide',
#   'shaft',
#   'grounding',
#   'on',
#   'both',
#   'ends',
#   'of',
#   'the',
#   'motor',
#   'or',
#   'use',
#   'an',
#   'insulated',
#   'bearing',
#   'on',
#   'the',
#   'non-drive',
#   'end',
#   'and',
#   'a',
#   'drive',
#   'end',
#   'shaft',
#   'grounding',
#   'system',
#   'to',
#   'break',
#   'the',
#   'current',
#   'loop.',
#   '3)',
#   'not',
#   'all',
#   'shaft',
#   'grounding',
#   'devices',
#   'are',
#   'equal.',
#   'it',
#   'is',
#   'certainly',
#   'confusing',
#   'with',
#   'the',
#   'different',
#   'available',
#   'products',
#   'on',
#   'the',
#   'market.',
#   'the',
#   'following',
#   'are',
#   'key',
#   'principals',
#   'that',
#   'cannot',
#   'be',
#   'ignored',
#   'while',
#   'researching',
#   'shaft',
#   'grounding',
#   'products.',
#   'always',
#   'have',
#   'these',
#   'concepts',
#   'and',
#   'questions',
#   'at',
#   'the',
#   'forefront',
#   'of',
#   'your',
#   'mind',
#   'when',
#   'researching',
#   'shaft',
#   'grounding',
#   'options:',
#   'the',
#   'grounding',
#   'system',
#   'must',
#   'be',
#   'a',
#   'better',
#   'competitor',
#   'to',
#   'the',
#   'bearing',
#   'for',
#   'grounding',
#   'the',
#   'voltage/current',
#   'away',
#   'from',
#   'the',
#   'bearing.',
#   'while',
#   'most',
#   'shaft',
#   'grounding',
#   'systems',
#   'lower',
#   'shaft',
#   'voltages',
#   'right',
#   'out',
#   'of',
#   'the',
#   'box,',
#   'not',
#   'all',
#   'shaft',
#   'grounding',
#   'systems',
#   'lower',
#   'voltages',
#   'below',
#   'the',
#   'threshold',
#   'to',
#   'prevent',
#   'current',
#   'flow',
#   'through',
#   'the',
#   'dielectric',
#   '(bearing',
#   'grease)',
#   'then',
#   'onto',
#   'the',
#   'bearing.',
#   'moreover,',
#   'most',
#   'shaft',
#   'grounding',
#   'systems',
#   'cannot',
#   'maintain',
#   'for',
#   'the',
#   'long-term',
#   'voltages',
#   'below',
#   'the',
#   'known',
#   'threshold.',
#   'one',
#   'major',
#   'manufacturer',
#   'of',
#   'shaft',
#   'grounding',
#   'rings',
#   '(sgrs)',
#   'was',
#   'asked',
#   'the',
#   'question',
#   'during',
#   'a',
#   'webinar',
#   '""how',
#   'do',
#   'you',
#   'know',
#   'the',
#   'grounding',
#   'system',
#   'is',
#   'working?""',
#   'and',
#   'their',
#   'response',
#   'was',
#   'if',
#   'the',
#   'shaft',
#   'voltage',
#   'readings',
#   'are',
#   'below',
#   '10v'],
#  ['since',
#   'last',
#   'one',
#   'month',
#   'we',
#   'observed',
#   'rise',
#   'in',
#   'high',
#   'frequency',
#   'component',
#   'at',
#   'motor',
#   'nde',
#   'brg.',
#   'of',
#   'pa',
#   'fan',
#   'motor',
#   '(nde',
#   'has',
#   'got',
#   '2',
#   'brgs.',
#   'nu230',
#   '&',
#   '6830',
#   ').sound',
#   'from',
#   'bearing',
#   'had',
#   'increased.we',
#   'are',
#   'using',
#   'emerson',
#   'csi',
#   '2130',
#   '.spectrum',
#   'showed',
#   'high',
#   'frequency',
#   'component',
#   'between',
#   '1to',
#   '20khz',
#   'around',
#   '26gse',
#   'which',
#   'got',
#   'reduced',
#   'after',
#   'greasing',
#   'to',
#   '15',
#   'gse',
#   'but',
#   'within',
#   '1',
#   'day',
#   'again',
#   'increased',
#   'back.',
#   'overall',
#   'vibration',
#   'increased',
#   'to',
#   '15mm/sec',
#   '(zero',
#   'to',
#   'peak).',
#   'in',
#   'peakvue',
#   'with',
#   '2k',
#   'hz',
#   'filter',
#   ',',
#   'bpfo',
#   'peaks',
#   'were',
#   'visible',
#   '(peakvue',
#   'value',
#   'around',
#   '18).',
#   'when',
#   'sound',
#   'increased',
#   'from',
#   'nde',
#   'brg.',
#   'even',
#   'more',
#   ',motor',
#   'was',
#   'replaced.',
#   'now',
#   'i',
#   'am',
#   'posting',
#   'nde',
#   'side',
#   'nu',
#   '230',
#   'inner',
#   'race',
#   'photos',
#   'and',
#   'de',
#   'side',
#   'nu230',
#   'photos',
#   'also',
#   ',please',
#   'confirm',
#   'the',
#   'bearing',
#   'defect.'],
#  ['innner', 'race', 'of', 'nu230', 'brg.', 'in', 'zoom', 'view.'],
#  ['yes,',
#   "that's",
#   'textbook',
#   'fluting.',
#   'there',
#   'have',
#   'been',
#   'many',
#   'good',
#   'discussions',
#   'here',
#   'about',
#   'it',
#   'over',
#   'the',
#   'years:',
#   'https://www.maintenance.org/top...63202347#77420702863'],
#  ['"first',
#   'time',
#   'on',
#   'this',
#   'blog',
#   'and',
#   'i',
#   'see',
#   'these',
#   'postings',
#   'are',
#   'a',
#   'couple',
#   'years',
#   'old,',
#   'but',
#   'here',
#   'goes',
#   'it',
#   'anyway:',
#   'i',
#   'reviewed',
#   'the',
#   'pictures',
#   'and',
#   'agree',
#   'you',
#   'are',
#   'experiencing',
#   'electrically',
#   'induced',
#   'bearing',
#   'failure.',
#   'incidence',
#   'rates',
#   'of',
#   'bearing',
#   'failure',
#   'on',
#   'vfd',
#   'motors',
#   'is',
#   'at',
#   'least',
#   '60%',
#   'by',
#   '2',
#   'years',
#   'and',
#   'only',
#   'continues',
#   'to',
#   'climb',
#   'from',
#   'there.',
#   'it',
#   'is',
#   'a',
#   'well-accepted',
#   'and',
#   'pervasive',
#   'problem',
#   'that',
#   'particularly',
#   'plagues',
#   'operations',
#   'that',
#   'run',
#   '24/7.',
#   'the',
#   'following',
#   'information',
#   'is',
#   'based',
#   'on',
#   'long-term',
#   'field',
#   'and',
#   'lab',
#   'studies',
#   'over',
#   '30',
#   'years.',
#   '1)',
#   'capacitive',
#   'discharge',
#   'through',
#   'the',
#   'bearing',
#   'is',
#   'a',
#   'local',
#   'event',
#   'caused',
#   'by',
#   'the',
#   'vfd',
#   'gated',
#   'mechanism',
#   'switching',
#   'on',
#   'and',
#   'off.',
#   'vfd',
#   'brands,',
#   'altering',
#   'the',
#   'carrier',
#   'frequency,',
#   'installing',
#   'induction',
#   'absorbers',
#   'on',
#   'the',
#   'wiring,',
#   'shunts,',
#   'conductive',
#   'grease,',
#   'etc.',
#   'are',
#   'not',
#   'a',
#   'fix',
#   'for',
#   'this',
#   'phenomenon.',
#   'a',
#   'shaft',
#   'grounding',
#   'device',
#   'is',
#   'the',
#   'only',
#   'known',
#   'way',
#   'to',
#   'economically',
#   'eliminate',
#   'capacitive',
#   'discharge',
#   'through',
#   'the',
#   'bearing.',
#   '2)',
#   'circulating',
#   'currents',
#   'can',
#   'be',
#   'present',
#   'on',
#   'larger',
#   'framed',
#   'motors',
#   'and',
#   'are',
#   'inherent',
#   'to',
#   'the',
#   'motor.',
#   'this',
#   'is',
#   'different',
#   'than',
#   'capacitive',
#   'coupling',
#   'as',
#   'described',
#   'above',
#   'under',
#   '#1.',
#   'our',
#   'field',
#   'research',
#   'has',
#   'shown',
#   'that',
#   'motors',
#   '100-200hp',
#   'and',
#   'with',
#   'rpm',
#   '<=1200',
#   'or',
#   'motors',
#   '>=200hp',
#   'regardless',
#   'of',
#   'rpm',
#   'are',
#   'susceptible',
#   'to',
#   'circulating',
#   'currents.',
#   'incident',
#   'rates',
#   'of',
#   'circulating',
#   'currents',
#   'being',
#   'present',
#   'is',
#   '25-35%',
#   'for',
#   'the',
#   'motor',
#   'parameters',
#   'described',
#   'above.',
#   'insulated',
#   'bearings',
#   'will',
#   'not',
#   'take',
#   'care',
#   'of',
#   'circulating',
#   'currents',
#   'as',
#   'the',
#   'current',
#   'will',
#   'find',
#   'a',
#   'parallel',
#   'pathway',
#   'and',
#   'take',
#   'out',
#   'bearings',
#   'in',
#   'connected',
#   'equipment.',
#   'a',
#   'typical',
#   'set-up',
#   'to',
#   'deal',
#   'with',
#   'circulating',
#   'currents',
#   'is',
#   'to',
#   'either',
#   'provide',
#   'shaft',
#   'grounding',
#   'on',
#   'both',
#   'ends',
#   'of',
#   'the',
#   'motor',
#   'or',
#   'use',
#   'an',
#   'insulated',
#   'bearing',
#   'on',
#   'the',
#   'non-drive',
#   'end',
#   'and',
#   'a',
#   'drive',
#   'end',
#   'shaft',
#   'grounding',
#   'system',
#   'to',
#   'break',
#   'the',
#   'current',
#   'loop.',
#   '3)',
#   'not',
#   'all',
#   'shaft',
#   'grounding',
#   'devices',
#   'are',
#   'equal.',
#   'it',
#   'is',
#   'certainly',
#   'confusing',
#   'with',
#   'the',
#   'different',
#   'available',
#   'products',
#   'on',
#   'the',
#   'market.',
#   'the',
#   'following',
#   'are',
#   'key',
#   'principals',
#   'that',
#   'cannot',
#   'be',
#   'ignored',
#   'while',
#   'researching',
#   'shaft',
#   'grounding',
#   'products.',
#   'always',
#   'have',
#   'these',
#   'concepts',
#   'and',
#   'questions',
#   'at',
#   'the',
#   'forefront',
#   'of',
#   'your',
#   'mind',
#   'when',
#   'researching',
#   'shaft',
#   'grounding',
#   'options:',
#   'the',
#   'grounding',
#   'system',
#   'must',
#   'be',
#   'a',
#   'better',
#   'competitor',
#   'to',
#   'the',
#   'bearing',
#   'for',
#   'grounding',
#   'the',
#   'voltage/current',
#   'away',
#   'from',
#   'the',
#   'bearing.',
#   'while',
#   'most',
#   'shaft',
#   'grounding',
#   'systems',
#   'lower',
#   'shaft',
#   'voltages',
#   'right',
#   'out',
#   'of',
#   'the',
#   'box,',
#   'not',
#   'all',
#   'shaft',
#   'grounding',
#   'systems',
#   'lower',
#   'voltages',
#   'below',
#   'the',
#   'threshold',
#   'to',
#   'prevent',
#   'current',
#   'flow',
#   'through',
#   'the',
#   'dielectric',
#   '(bearing',
#   'grease)',
#   'then',
#   'onto',
#   'the',
#   'bearing.',
#   'moreover,',
#   'most',
#   'shaft',
#   'grounding',
#   'systems',
#   'cannot',
#   'maintain',
#   'for',
#   'the',
#   'long-term',
#   'voltages',
#   'below',
#   'the',
#   'known',
#   'threshold.',
#   'one',
#   'major',
#   'manufacturer',
#   'of',
#   'shaft',
#   'grounding',
#   'rings',
#   '(sgrs)',
#   'was',
#   'asked',
#   'the',
#   'question',
#   'during',
#   'a',
#   'webinar',
#   '""how',
#   'do',
#   'you',
#   'know',
#   'the',
#   'grounding',
#   'system',
#   'is',
#   'working?""',
#   'and',
#   'their',
#   'response',
#   'was',
#   'if',
#   'the',
#   'shaft',
#   'voltage',
#   'readings',
#   'are',
#   'below',
#   '10v'],
#  ['the',
#   'machine',
#   'is',
#   'turbo',
#   'generator',
#   ',',
#   'the',
#   'gas',
#   'turbine',
#   'is',
#   'ge',
#   'frame',
#   '1.',
#   'fire',
#   'incident',
#   'happened',
#   'in',
#   'gt',
#   'side',
#   'due',
#   'to',
#   'lube',
#   'oil',
#   'leakage',
#   'either',
#   'internal',
#   'or',
#   'external',
#   'not',
#   'confirmed',
#   'yet.',
#   'upon',
#   'inspection',
#   ',',
#   'the',
#   'babbitt',
#   'material',
#   'loss',
#   'found',
#   'in',
#   'bearing#3',
#   '(see',
#   'attached',
#   'crossection',
#   ')',
#   'at',
#   'lp',
#   'rotor.',
#   'also',
#   'coke',
#   'or',
#   'tar',
#   'found',
#   'at',
#   'lp',
#   'bucket.',
#   'all',
#   'relevant',
#   'pics',
#   'and',
#   'gt',
#   'crossection',
#   'dwg',
#   'attached',
#   '.',
#   'the',
#   'questions',
#   'are:',
#   '1)',
#   'whatâ€™s',
#   'the',
#   'origin',
#   'of',
#   'lube',
#   'oil',
#   'leakage',
#   'external',
#   'or',
#   'internal',
#   '?',
#   'is',
#   'it',
#   'split',
#   'from',
#   'bearing',
#   'housing',
#   'or',
#   'lube',
#   'oil',
#   'supply',
#   'pipe',
#   'leakages',
#   '?',
#   '2)',
#   'whatâ€™s',
#   'the',
#   'root',
#   'cause',
#   'of',
#   'lube',
#   'oil',
#   'leakage',
#   '?',
#   '3)',
#   'whatâ€™s',
#   'the',
#   'root',
#   'cause',
#   'of',
#   'babbit',
#   'materials',
#   'loss',
#   'at',
#   'lower',
#   'part',
#   'of',
#   'brg#3?',
#   'pics',
#   'attached',
#   '4)',
#   'how',
#   'the',
#   'coke',
#   'or',
#   'tar',
#   'formed',
#   'at',
#   'lp',
#   'buckets',
#   '?',
#   'pic',
#   'attached'],
#  ['the', 'pic', 'of', 'failed', 'bearing', '#3', 'is', 'also', 'attached.'],
#  ['i',
#   'do',
#   'not',
#   'have',
#   'experience',
#   'on',
#   'frame',
#   '1',
#   'but',
#   'i',
#   'think',
#   'you',
#   'should',
#   'check',
#   'some',
#   'information',
#   'and',
#   'answer',
#   'for',
#   'yourself',
#   'that:',
#   '1.',
#   'the',
#   'leakage',
#   'oil',
#   'just',
#   'happen',
#   'at',
#   'bearing',
#   '#3',
#   'or',
#   'at',
#   'all',
#   'bearings?',
#   '2.',
#   'have',
#   'you',
#   'checked',
#   'the',
#   'oil',
#   'drain',
#   'piping',
#   'for',
#   'any',
#   'plug/stuck?',
#   '3.',
#   'there',
#   'is',
#   'buffer',
#   'air',
#   'supplied',
#   'to',
#   'labyrinth',
#   'seal,',
#   "isn't",
#   'it?',
#   'if',
#   'any,',
#   'have',
#   'you',
#   'checked',
#   'the',
#   'buffer',
#   'air',
#   'lines?',
#   '4.',
#   'how',
#   'about',
#   'oil',
#   'vapour',
#   'system?',
#   '5.',
#   'have',
#   'you',
#   'checked',
#   'the',
#   'bearing',
#   'temp?',
#   'when',
#   'is',
#   'it',
#   'increased?',
#   'the',
#   'same',
#   'for',
#   'vibration?',
#   'if',
#   'the',
#   'fire',
#   'happen',
#   'in',
#   'the',
#   'moment',
#   'of',
#   'gt',
#   'running,',
#   'i',
#   'think',
#   'that',
#   'the',
#   'oil',
#   'leakage',
#   'happen',
#   'from',
#   'internal',
#   '(if',
#   'from',
#   'external,',
#   'i',
#   'believe',
#   'someone',
#   'seen',
#   'and',
#   'announced).',
#   'the',
#   'bearing',
#   'look',
#   'like',
#   'running',
#   'under',
#   'too',
#   'high',
#   'temp.',
#   'the',
#   'oil',
#   'under',
#   'high',
#   'temperature',
#   '(over',
#   '200oc)',
#   'will',
#   'form',
#   'coke.'],
#  ['ngo',
#   'dinh',
#   'posted:',
#   'i',
#   'do',
#   'not',
#   'have',
#   'experience',
#   'on',
#   'frame',
#   '1',
#   'but',
#   'i',
#   'think',
#   'you',
#   'should',
#   'check',
#   'some',
#   'information',
#   'and',
#   'answer',
#   'for',
#   'yourself',
#   'that:',
#   '1.',
#   'the',
#   'leakage',
#   'oil',
#   'just',
#   'happen',
#   'at',
#   'bearing',
#   '#3',
#   'or',
#   'at',
#   'all',
#   'bearings?',
#   'total',
#   '4',
#   'bearings,',
#   'all',
#   'bearings',
#   'checked',
#   ',',
#   'only',
#   'bearing#3',
#   'found',
#   'with',
#   'babbitt',
#   'material',
#   'lost.',
#   'other',
#   '3',
#   'bearings',
#   'found',
#   'normal.',
#   '2.',
#   'have',
#   'you',
#   'checked',
#   'the',
#   'oil',
#   'drain',
#   'piping',
#   'for',
#   'any',
#   'plug/stuck?',
#   'yes',
#   'checked',
#   ',',
#   'no',
#   'obstruction',
#   'or',
#   'plugging',
#   'observed.',
#   '3.',
#   'there',
#   'is',
#   'buffer',
#   'air',
#   'supplied',
#   'to',
#   'labyrinth',
#   'seal,',
#   "isn't",
#   'it?',
#   'if',
#   'any,',
#   'have',
#   'you',
#   'checked',
#   'the',
#   'buffer',
#   'air',
#   'lines?',
#   'yes,',
#   'seal',
#   'air',
#   'has',
#   'been',
#   'taken',
#   'from',
#   '10th',
#   'stage',
#   'of',
#   'axial',
#   'compressor,',
#   'air',
#   'supply',
#   'lines',
#   'have',
#   'been',
#   'checked',
#   'and',
#   'found',
#   'normal',
#   'for',
#   'required',
#   'seal',
#   'air',
#   'pressure.',
#   '4.',
#   'how',
#   'about',
#   'oil',
#   'vapour',
#   'system?',
#   'please',
#   'elaborate',
#   'further',
#   'on',
#   'this??',
#   '5.',
#   'have',
#   'you',
#   'checked',
#   'the',
#   'bearing',
#   'temp?',
#   'when',
#   'is',
#   'it',
#   'increased?',
#   'the',
#   'same',
#   'for',
#   'vibration?',
#   'under',
#   'review.',
#   'if',
#   'the',
#   'fire',
#   'happen',
#   'in',
#   'the',
#   'moment',
#   'of',
#   'gt',
#   'running,',
#   'i',
#   'think',
#   'that',
#   'the',
#   'oil',
#   'leakage',
#   'happen',
#   'from',
#   'internal',
#   '(if',
#   'from',
#   'external,',
#   'i',
#   'believe',
#   'someone',
#   'seen',
#   'and',
#   'announced).',
#   'fire',
#   'smoke',
#   'has',
#   'been',
#   'observed',
#   'in',
#   'exhaust',
#   'duct',
#   'of',
#   'gt,',
#   'soon',
#   'after',
#   'gt',
#   'enclosure',
#   'was',
#   'opened',
#   'and',
#   'fire',
#   'was',
#   'seen,',
#   'in',
#   '1st',
#   'thought,',
#   'lo',
#   'pump',
#   'was',
#   'shutdown',
#   'and',
#   'fire',
#   'was',
#   'removed,',
#   'once',
#   'lo',
#   'pump',
#   'started',
#   'again,',
#   'the',
#   'fire',
#   'happened',
#   'again',
#   'then',
#   'again',
#   'the',
#   'l.o',
#   'pump',
#   'was',
#   'shutdown',
#   'and',
#   'fire',
#   'removed.',
#   'fire',
#   'is',
#   'for',
#   'sure',
#   'due',
#   'to',
#   'l.o',
#   'leakage',
#   ',',
#   'but',
#   'still',
#   'mystery',
#   'from',
#   'where',
#   'the',
#   'oil',
#   'leaked',
#   'and',
#   'how',
#   'the',
#   'fire',
#   'caught?',
#   'and',
#   'how',
#   'the',
#   'l.o',
#   'penetrated',
#   'at',
#   'lp',
#   'rotor',
#   'bucket',
#   'and',
#   'formed',
#   'coking/tar',
#   'since',
#   'l.o',
#   'pressure',
#   'is',
#   'lesser',
#   'than',
#   'the',
#   'turbine',
#   'pressure??',
#   'the',
#   'bearing',
#   'look',
#   'like',
#   'running',
#   'under',
#   'too',
#   'high',
#   'temp.',
#   'the',
#   'oil',
#   'under',
#   'high',
#   'temperature',
#   '(over',
#   '200oc)',
#   'will',
#   'form',
#   'coke.',
#   'the',
#   'bearing#3',
#   'damage',
#   'looks',
#   'secondary',
#   'damage',
#   'due',
#   'to',
#   'fire',
#   'and',
#   'dry',
#   'running',
#   'of',
#   'lp',
#   'rotor',
#   '(since',
#   'l.o',
#   'pump',
#   'was',
#   'stopped)',
#   'how',
#   'the',
#   'fire',
#   'happened',
#   ',',
#   'still',
#   'dont',
#   'know?',
#   '?'],
#  ['the',
#   'ventilation',
#   'fan',
#   'was',
#   'also',
#   'tripped',
#   'due',
#   'to',
#   'breakage',
#   'of',
#   'its',
#   'belt',
#   'which',
#   'may',
#   'increase',
#   'the',
#   't',
#   'of',
#   'enclosure',
#   'and',
#   'which',
#   'further',
#   'melt',
#   'the',
#   'babbitt',
#   'white',
#   'metal',
#   'which',
#   'leads',
#   'to',
#   'bearing',
#   'failure',
#   '??',
#   'i',
#   'am',
#   'not',
#   'sure,',
#   'can',
#   'u',
#   'recognize',
#   'from',
#   'bearing',
#   'pic,',
#   'is',
#   'it',
#   'melted',
#   'during',
#   'running',
#   'or',
#   'stationary?',
#   'or',
#   'is',
#   'it',
#   'melted',
#   'due',
#   'to',
#   'high',
#   'lo',
#   'temp???',
#   'i',
#   'am',
#   'not',
#   'sure'],
#  ['it',
#   'is',
#   'possible',
#   'that',
#   'the',
#   'shaft',
#   'is',
#   'been',
#   'hot',
#   'due',
#   'to',
#   'fire',
#   'and',
#   'make',
#   'the',
#   'babbit',
#   'overheat',
#   'like',
#   'picture.',
#   'you',
#   'should',
#   'take',
#   'event',
#   'sequence',
#   'and',
#   'see',
#   'what',
#   'happen',
#   'near',
#   'the',
#   'event',
#   'time.',
#   'focus',
#   'to',
#   'oil',
#   'system',
#   'and',
#   'clearance,',
#   'i',
#   'think',
#   'you',
#   'will',
#   'get',
#   'your',
#   'answer.'],
#  ['during',
#   'inspection,',
#   'the',
#   'brass',
#   'oil',
#   'seal',
#   'was',
#   'found',
#   'damaged.',
#   'so,',
#   'there',
#   'is',
#   'a',
#   'possibility',
#   'the',
#   'oil',
#   'could',
#   'leak',
#   'from',
#   'brg#4',
#   'and',
#   'got',
#   'fire,',
#   'but',
#   'question',
#   'is',
#   'why',
#   'bearing#4',
#   'which',
#   'is',
#   'near',
#   'to',
#   'fire',
#   'location',
#   'is',
#   'not',
#   'melted',
#   'and',
#   'how',
#   'the',
#   'fire',
#   'traveled',
#   'from',
#   'brg#4',
#   'towards',
#   'brg#3',
#   '?',
#   'you',
#   'know',
#   'its',
#   'turbine',
#   'section',
#   ',',
#   'the',
#   'pressure',
#   'at',
#   'brg#3',
#   'is',
#   'higher',
#   'than',
#   'the',
#   'pressure',
#   'at',
#   'brg#4'],
#  ['we',
#   'have',
#   'siemens',
#   'sgt',
#   '300',
#   '(',
#   '7.5',
#   'mw)',
#   'gas',
#   'turbine',
#   'generator.',
#   'during',
#   'starting',
#   'of',
#   'this',
#   'machine',
#   'heavy',
#   'vibration',
#   'observed',
#   'and',
#   'machine',
#   'tripped',
#   'at',
#   '9000',
#   'rpm',
#   'on',
#   'high',
#   'vibration',
#   '(',
#   'vibration',
#   'tripping',
#   'set',
#   'at',
#   '90',
#   'microns).',
#   'more',
#   'than',
#   '15',
#   'trial',
#   'taken',
#   'in',
#   'this',
#   'machine',
#   'neglecting',
#   'vibration.',
#   'on',
#   'opening',
#   'this',
#   'machine',
#   'cold',
#   'end',
#   'bearing',
#   'found',
#   'damage.',
#   'photographs',
#   'attached.',
#   'what',
#   'is',
#   'probable',
#   'reason',
#   'for',
#   'this',
#   'bearing',
#   'failure?',
#   '?'],
#  ['dear',
#   'sir',
#   ',',
#   'its',
#   'clear',
#   'that',
#   'the',
#   'bearing',
#   'has',
#   'continuous',
#   'rub',
#   ',',
#   'primary',
#   'suspect',
#   'on',
#   'lubrication',
#   '.but',
#   'we',
#   'could',
#   'find',
#   'the',
#   'root',
#   'cause',
#   ',',
#   'if',
#   'we',
#   'have',
#   'vibration',
#   'spectrum',
#   ',orbit',
#   'plots',
#   'or',
#   'shaft',
#   'center',
#   'lone',
#   'data',
#   ',please',
#   'post',
#   'if',
#   'you',
#   'have',
#   'any',
#   '.'],
#  ['pawannlng',
#   'posted:',
#   'we',
#   'have',
#   'siemens',
#   'sgt',
#   '300',
#   '(',
#   '7.5',
#   'mw)',
#   'gas',
#   'turbine',
#   'generator.',
#   'during',
#   'starting',
#   'of',
#   'this',
#   'machine',
#   'heavy',
#   'vibration',
#   'observed',
#   'and',
#   'machine',
#   'tripped',
#   'at',
#   '9000',
#   'rpm',
#   'on',
#   'high',
#   'vibration',
#   '(',
#   'vibration',
#   'tripping',
#   'set',
#   'at',
#   '90',
#   'microns).',
#   'more',
#   'than',
#   '15',
#   'trial',
#   'taken',
#   'in',
#   'this',
#   'machine',
#   'neglecting',
#   'vibration.',
#   'on',
#   'opening',
#   'this',
#   'machine',
#   'cold',
#   'end',
#   'bearing',
#   'found',
#   'damage.',
#   'photographs',
#   'attached.',
#   'what',
#   'is',
#   'probable',
#   'reason',
#   'for',
#   'this',
#   'bearing',
#   'failure??',
#   'hi',
#   'pawannlng,',
#   'why',
#   'it',
#   'need',
#   'to',
#   'neglect',
#   'the',
#   'vibration?',
#   'could',
#   'you',
#   'share',
#   'plot',
#   'if',
#   'any',
#   'like',
#   'shaft',
#   'centerline,',
#   'sequence',
#   'of',
#   'orbit',
#   'and',
#   'time',
#   'signal,',
#   'bode',
#   'and',
#   'polar',
#   'possible.',
#   'when',
#   'is',
#   'the',
#   'last',
#   'time',
#   'taken',
#   'oil',
#   'analysis',
#   'prior',
#   'this',
#   'incident?',
#   'regards,',
#   'rg'],
#  ['dear',
#   'sir',
#   'oil',
#   'analysis',
#   'was',
#   'done',
#   'six',
#   'month',
#   'back',
#   'and',
#   'report',
#   'was',
#   'normal.',
#   'i',
#   'am',
#   'attaching',
#   'only',
#   'available',
#   'vibration',
#   'plot.'],
#  ['dear',
#   'pawan,',
#   'without',
#   'referring',
#   'the',
#   'diagnostic',
#   'plots',
#   'i',
#   'think',
#   'its',
#   'very',
#   'difficult',
#   'to',
#   'pin',
#   'point',
#   'the',
#   'root',
#   'causes',
#   'of',
#   'the',
#   'failure.',
#   'for',
#   'fluid',
#   'film',
#   'tilting',
#   'pad',
#   'bearings,',
#   'we',
#   'need',
#   'to',
#   'refer',
#   'more',
#   'plots',
#   'and',
#   'one',
#   'plot',
#   'may',
#   'not',
#   'give',
#   'clear',
#   'conclusion.',
#   'my',
#   'opinion,',
#   'since',
#   'i',
#   'am',
#   'practicing',
#   'vibration',
#   'analyst',
#   'more',
#   'into',
#   'this',
#   'type',
#   'of',
#   'bearings.',
#   'for',
#   'hydro',
#   'machines',
#   'this',
#   'type',
#   'bearings',
#   'are',
#   'commonly',
#   'used.',
#   'sherub'],
#  ['dear',
#   'pawannlng,',
#   'the',
#   'possibles',
#   'causes',
#   'are:',
#   '1.-',
#   'misalignment',
#   '(external',
#   'misalignment)',
#   '2.-',
#   'bearing',
#   'housing',
#   'excentricity',
#   '(internal',
#   'misalignment)',
#   '3.-',
#   'low',
#   'lub',
#   'oil',
#   'pressure',
#   'in',
#   'bearing',
#   'or',
#   'any',
#   'restriction',
#   'in',
#   'lub',
#   'line.',
#   '4.-',
#   'over',
#   'radial',
#   'load.',
#   '5.-',
#   'preload',
#   'in',
#   'bearing',
#   '(internal',
#   'or',
#   'external)',
#   'we',
#   'can',
#   'rule',
#   'out',
#   'the',
#   'last',
#   'possibles',
#   'causes',
#   'using',
#   'technologies',
#   'that',
#   'rotating',
#   'guy',
#   'said',
#   '(shaft',
#   'centerline,',
#   'sequence',
#   'of',
#   'orbit',
#   'and',
#   'time',
#   'signal,',
#   'bode',
#   'and',
#   'polar',
#   'possible,',
#   'spectrum,',
#   'etc).'],
#  ['please',
#   'check',
#   'out',
#   'attached',
#   'bearing',
#   'failure',
#   'picture.',
#   'bearing',
#   'failed',
#   'within',
#   '200',
#   'hours',
#   'after',
#   'replacement.',
#   'equipment:',
#   'centrifugal',
#   'pump(flowserev',
#   'cpx)',
#   'for',
#   'water',
#   'service',
#   'bearing:',
#   'skf',
#   '3309',
#   'c3(de)',
#   'and',
#   'skf',
#   '6309',
#   'c3(nde)',
#   'bearing',
#   'failed',
#   '3309',
#   'c3',
#   'oil',
#   'lubricated',
#   'bearing',
#   'vg',
#   '68',
#   'running',
#   'rpm:',
#   '900-1100',
#   'alignment',
#   'was',
#   'under',
#   'range',
#   'of',
#   '0.05mm',
#   'previous',
#   'bearing',
#   'life',
#   'was',
#   'more',
#   'than',
#   '10000',
#   'hours',
#   'what',
#   'could',
#   'be',
#   'reason',
#   'for',
#   'this',
#   'failure?',
#   'axial/radial',
#   'load,',
#   'dirt',
#   'in',
#   'oil,',
#   'bearing',
#   'manufacturing',
#   'defects',
#   '?',
#   'brief',
#   'answer',
#   'is',
#   'apprenticed',
#   'note:',
#   'its',
#   'double',
#   'raw',
#   'angular',
#   'contact',
#   'ball',
#   'bearing',
#   'with',
#   'metal',
#   'cage.',
#   '(cage',
#   'removed',
#   'while',
#   'taking',
#   'picture)'],
#  ['the',
#   'bearing',
#   'is',
#   'indicating',
#   'excessive',
#   'axial',
#   'loading',
#   'for',
#   'some',
#   'reason.',
#   'it',
#   'does',
#   'not',
#   'indicate',
#   'the',
#   'presence',
#   'of',
#   'excessive',
#   'heat.',
#   'is',
#   'it',
#   'possible,',
#   'the',
#   'lubricant',
#   'was',
#   'not',
#   'correct',
#   'or',
#   'incorrect',
#   'amount?',
#   'but',
#   'that',
#   'would',
#   'indicate',
#   'excessive',
#   'heat.',
#   'this',
#   'was',
#   'not',
#   'a',
#   'manufacturing',
#   'defect',
#   'anything',
#   'related',
#   'to',
#   'the',
#   'bearing.',
#   'could',
#   'the',
#   'bearing',
#   'have',
#   'possibly',
#   'been',
#   'cocked',
#   'on',
#   'the',
#   'shaft?',
#   'i',
#   'have',
#   'seen',
#   'that',
#   'once',
#   'before,',
#   'where',
#   'the',
#   'bearing',
#   'was',
#   'not',
#   'seated',
#   'correctly',
#   'against',
#   'the',
#   'shoulder',
#   'of',
#   'the',
#   'journal.',
#   'find',
#   'the',
#   'reason',
#   'for',
#   'axial',
#   'loading',
#   'and',
#   'you',
#   'will',
#   'find',
#   'the',
#   'problem.'],
#  ['johnny',
#   '5',
#   'posted:',
#   'the',
#   'bearing',
#   'is',
#   'indicating',
#   'excessive',
#   'axial',
#   'loading',
#   'for',
#   'some',
#   'reason.',
#   'it',
#   'does',
#   'not',
#   'indicate',
#   'the',
#   'presence',
#   'of',
#   'excessive',
#   'heat.',
#   'is',
#   'it',
#   'possible,',
#   'the',
#   'lubricant',
#   'was',
#   'not',
#   'correct',
#   'or',
#   'incorrect',
#   'amount?',
#   'but',
#   'that',
#   'would',
#   'indicate',
#   'excessive',
#   'heat.',
#   'this',
#   'was',
#   'not',
#   'a',
#   'manufacturing',
#   'defect',
#   'anything',
#   'related',
#   'to',
#   'the',
#   'bearing.',
#   'could',
#   'the',
#   'bearing',
#   'have',
#   'possibly',
#   'been',
#   'cocked',
#   'on',
#   'the',
#   'shaft?',
#   'i',
#   'have',
#   'seen',
#   'that',
#   'once',
#   'before,',
#   'where',
#   'the',
#   'bearing',
#   'was',
#   'not',
#   'seated',
#   'correctly',
#   'against',
#   'the',
#   'shoulder',
#   'of',
#   'the',
#   'journal.',
#   'find',
#   'the',
#   'reason',
#   'for',
#   'axial',
#   'loading',
#   'and',
#   'you',
#   'will',
#   'find',
#   'the',
#   'problem.',
#   'hey',
#   'thanks',
#   'for',
#   'reply.',
#   'i',
#   'think',
#   'your',
#   'doubt',
#   'about',
#   'cocked',
#   'bearing',
#   'is',
#   'absolutely',
#   'right.',
#   'because',
#   'there',
#   'was',
#   'spacer',
#   'between',
#   'bearing&housing',
#   'in',
#   'axial',
#   'direction,',
#   'which',
#   'was',
#   'out',
#   'of',
#   'position',
#   'in',
#   'small',
#   'portion.',
#   '(we',
#   'observed',
#   'it',
#   'in',
#   'disassembly).',
#   'at',
#   'that',
#   'time',
#   'i',
#   'thought',
#   'it',
#   'occurred',
#   'due',
#   'to',
#   'disassembly.',
#   'thank',
#   'you',
#   'for',
#   'clarifying',
#   'my',
#   'confusion.'],
#  ['hi',
#   'friends,',
#   'in',
#   'one',
#   'of',
#   'our',
#   'ht',
#   'motor',
#   'we',
#   'found',
#   'inner',
#   'race',
#   'defect',
#   'with',
#   'side',
#   'bands',
#   'of',
#   '1xrpm',
#   'in',
#   'the',
#   'spectrum',
#   'and',
#   'yesterday',
#   'we',
#   'inspected',
#   'the',
#   'bearing',
#   'and',
#   'found',
#   'inner',
#   'race',
#   'was',
#   'cracked.but',
#   'the',
#   'history',
#   'of',
#   'the',
#   'equipment',
#   'says',
#   'it',
#   'has',
#   'already',
#   'two',
#   'breakdowns',
#   'with',
#   'inner',
#   'race',
#   'problem.during',
#   'the',
#   'first',
#   'time',
#   'inner',
#   'race',
#   'was',
#   'having',
#   'dent',
#   'and',
#   'during',
#   'second',
#   'time',
#   'inner',
#   'race',
#   'got',
#   'seized.',
#   'equipment',
#   'details',
#   'motor',
#   'rpm:1489',
#   'motor',
#   'kw:1600',
#   'nde',
#   'bearing:nu',
#   '228',
#   'de',
#   'bearing:nu',
#   '234',
#   '+',
#   '6234',
#   'application:cement',
#   'grinding',
#   'what',
#   'could',
#   'be',
#   'the',
#   'cause',
#   'of',
#   'repetitive',
#   'inner',
#   'race',
#   'damage',
#   '???',
#   'thanks',
#   'in',
#   'advance.'],
#  ['hi',
#   'vidya,',
#   'how',
#   'many',
#   'months',
#   'before',
#   'the',
#   'previous',
#   'failing',
#   'of',
#   'inner',
#   'race',
#   'was?',
#   'do',
#   'you',
#   'have',
#   'any',
#   'monitoring',
#   'device',
#   'or',
#   'just',
#   'a',
#   'scheduled',
#   'monitoring?',
#   'in',
#   'my',
#   'previous',
#   'experience,',
#   'we',
#   'get',
#   'this',
#   'inner',
#   'race',
#   'failure',
#   'when',
#   'bearing',
#   'fit',
#   'and',
#   'clearance',
#   'was',
#   'not',
#   'achieve.',
#   'regards,'],
#  ['hi',
#   'rg,',
#   'previous',
#   'failure',
#   'was',
#   '2',
#   'years',
#   'back',
#   'and',
#   'we',
#   'use',
#   'spm',
#   'instrument',
#   'for',
#   'condition',
#   'monitoring.does',
#   'fitment',
#   'and',
#   'clearance',
#   'is',
#   'the',
#   'cause',
#   'for',
#   'three',
#   'failures??',
#   'any',
#   'problem',
#   'due',
#   'to',
#   'load',
#   '??',
#   '?'],
#  ['vidya,',
#   'how',
#   'much',
#   'is',
#   'the',
#   'amount',
#   'of',
#   'impacting',
#   'before',
#   'this',
#   'happen?',
#   'is',
#   'there',
#   'a',
#   'temperature',
#   'increase',
#   'before?',
#   'after',
#   'that',
#   'crack',
#   'when',
#   'you',
#   'ovehaul,',
#   'did',
#   'the',
#   'inner',
#   'race',
#   'spun',
#   'on',
#   'the',
#   'shaft?',
#   'regards,'],
#  ['rg,',
#   'there',
#   'is',
#   'no',
#   'significant',
#   'increase',
#   'in',
#   'temperature',
#   'and',
#   'yes',
#   'inner',
#   'race',
#   'spun',
#   'on',
#   'shaft.',
#   'i',
#   "didn't",
#   'get',
#   'what',
#   'exactly',
#   'impacts',
#   'u',
#   'are',
#   'asking,whether',
#   'the',
#   'load',
#   'or',
#   'in',
#   'twf?',
#   '?'],
#  ['measure',
#   'the',
#   'bearing',
#   'fit',
#   'on',
#   'the',
#   'shaft,',
#   'maybe',
#   "it's",
#   'way',
#   'over',
#   'sized.'],
#  ['vidya',
#   'sagar',
#   'posted:',
#   'hi',
#   'rg,',
#   'previous',
#   'failure',
#   'was',
#   '2',
#   'years',
#   'back',
#   'and',
#   'we',
#   'use',
#   'spm',
#   'instrument',
#   'for',
#   'condition',
#   'monitoring.does',
#   'fitment',
#   'and',
#   'clearance',
#   'is',
#   'the',
#   'cause',
#   'for',
#   'three',
#   'failures??',
#   'any',
#   'problem',
#   'due',
#   'to',
#   'load',
#   '???',
#   'im',
#   'just',
#   'curious',
#   'that',
#   'this',
#   'is',
#   'sudden',
#   'failure',
#   'or',
#   'the',
#   'failure',
#   'developed?',
#   'i',
#   'doubt',
#   'at',
#   'the',
#   'data',
#   'collection',
#   'since',
#   'this',
#   'is',
#   'not',
#   'sees',
#   'that',
#   'will',
#   'generate',
#   'fault.',
#   'regards,'],
#  ['dear',
#   'all',
#   'we',
#   'have',
#   'an',
#   'issue',
#   'high',
#   'vibration',
#   'on',
#   'brg',
#   '#2&3',
#   ',',
#   'finish',
#   'the',
#   'major',
#   'inspection',
#   'on',
#   'this',
#   'unit',
#   'when',
#   'we',
#   'start',
#   'the',
#   'unit',
#   ',',
#   'at',
#   'fsnl',
#   '(',
#   '3000',
#   'rpm',
#   ')',
#   'the',
#   'vibration',
#   'for',
#   'brg',
#   '#',
#   '2&3',
#   'stable',
#   'not',
#   'exceed',
#   '(6',
#   'mm/s',
#   ')',
#   ',',
#   'when',
#   'the',
#   'unit',
#   'is',
#   'loaded',
#   'the',
#   'vibration',
#   'increase',
#   'on',
#   'brg',
#   '2&3',
#   'only',
#   ',',
#   'at',
#   'full',
#   'load',
#   'the',
#   'vibration',
#   'reach',
#   'on',
#   'brg',
#   '#',
#   '(',
#   '9-',
#   '13',
#   'mm/s',
#   'fluctuating',
#   ')',
#   'and',
#   'brg',
#   '#3',
#   '(',
#   '7-',
#   '8.5',
#   'mm/s',
#   ')',
#   ',',
#   'and',
#   'in',
#   'the',
#   'mi',
#   'inspection',
#   'we',
#   'made',
#   'casing',
#   'alignment',
#   'as',
#   'recommended',
#   'from',
#   'manufacturer',
#   'ge',
#   'because',
#   'when',
#   'open',
#   'the',
#   'unit',
#   'we',
#   'found',
#   'the',
#   'brg',
#   '#',
#   '2',
#   'is',
#   'damage',
#   'from',
#   'upper',
#   'haif',
#   'and',
#   'brg',
#   '#',
#   '3',
#   'is',
#   'damage',
#   'on',
#   'lower',
#   'haif',
#   'and',
#   'there',
#   'is',
#   'oval',
#   'on',
#   'aft',
#   'compressor',
#   'casing',
#   'and',
#   'before',
#   'open',
#   'unit',
#   'the',
#   'vibration',
#   'on',
#   'brg',
#   '#',
#   '2',
#   'reached',
#   '(',
#   'up',
#   'to',
#   '19mm/s',
#   ')',
#   ',',
#   'all',
#   'bearing',
#   'replaced',
#   'by',
#   'new',
#   'ones',
#   'and',
#   'the',
#   'vibration',
#   'still',
#   ',',
#   'please',
#   'to',
#   'advice',
#   'me',
#   'to',
#   'know',
#   'what',
#   'is',
#   'the',
#   'cause',
#   'of',
#   'vibration',
#   '.',
#   'note',
#   ':',
#   'all',
#   'vibration',
#   'on',
#   'brg',
#   '#',
#   '4',
#   '&',
#   '5',
#   'are',
#   'smooth',
#   'not',
#   'exceed',
#   '(2mm/s',
#   ')at',
#   'full',
#   'load',
#   'thanks',
#   'in',
#   'advance'],
#  ['ahmad',
#   'alfakeer',
#   'posted:',
#   'dear',
#   'all',
#   'we',
#   'have',
#   'an',
#   'issue',
#   'high',
#   'vibration',
#   'on',
#   'brg',
#   '#2&3',
#   ',',
#   'finish',
#   'the',
#   'major',
#   'inspection',
#   'on',
#   'this',
#   'unit',
#   'when',
#   'we',
#   'start',
#   'the',
#   'unit',
#   ',',
#   'at',
#   'fsnl',
#   '(',
#   '3000',
#   'rpm',
#   ')',
#   'the',
#   'vibration',
#   'for',
#   'brg',
#   '#',
#   '2&3',
#   'stable',
#   'not',
#   'exceed',
#   '(6',
#   'mm/s',
#   ')',
#   ',',
#   'when',
#   'the',
#   'unit',
#   'is',
#   'loaded',
#   'the',
#   'vibration',
#   'increase',
#   'on',
#   'brg',
#   '2&3',
#   'only',
#   ',',
#   'at',
#   'full',
#   'load',
#   'the',
#   'vibration',
#   'reach',
#   'on',
#   'brg',
#   '#',
#   '(',
#   '9-',
#   '13',
#   'mm/s',
#   'fluctuating',
#   ')',
#   'and',
#   'brg',
#   '#3',
#   '(',
#   '7-',
#   '8.5',
#   'mm/s',
#   ')',
#   ',',
#   'and',
#   'in',
#   'the',
#   'mi',
#   'inspection',
#   'we',
#   'made',
#   'casing',
#   'alignment',
#   'as',
#   'recommended',
#   'from',
#   'manufacturer',
#   'ge',
#   'because',
#   'when',
#   'open',
#   'the',
#   'unit',
#   'we',
#   'found',
#   'the',
#   'brg',
#   '#',
#   '2',
#   'is',
#   'damage',
#   'from',
#   'upper',
#   'haif',
#   'and',
#   'brg',
#   '#',
#   '3',
#   'is',
#   'damage',
#   'on',
#   'lower',
#   'haif',
#   'and',
#   'there',
#   'is',
#   'oval',
#   'on',
#   'aft',
#   'compressor',
#   'casing',
#   'and',
#   'before',
#   'open',
#   'unit',
#   'the',
#   'vibration',
#   'on',
#   'brg',
#   '#',
#   '2',
#   'reached',
#   '(',
#   'up',
#   'to',
#   '19mm/s',
#   ')',
#   ',',
#   'all',
#   'bearing',
#   'replaced',
#   'by',
#   'new',
#   'ones',
#   'and',
#   'the',
#   'vibration',
#   'still',
#   ',',
#   'please',
#   'to',
#   'advice',
#   'me',
#   'to',
#   'know',
#   'what',
#   'is',
#   'the',
#   'cause',
#   'of',
#   'vibration',
#   '.',
#   'note',
#   ':',
#   'all',
#   'vibration',
#   'on',
#   'brg',
#   '#',
#   '4',
#   '&',
#   '5',
#   'are',
#   'smooth',
#   'not',
#   'exceed',
#   '(2mm/s',
#   ')at',
#   'full',
#   'load',
#   'thanks',
#   'in',
#   'advance',
#   'please',
#   'to',
#   'help',
#   'me',
#   '??',
#   '?'],
#  ['first,',
#   'i',
#   'think',
#   'you',
#   'should',
#   'give',
#   'us',
#   'some',
#   'data',
#   '(apht',
#   'trend,',
#   'waterfall,',
#   'scl,',
#   'orbit...',
#   'if',
#   'any)for',
#   'review',
#   'and',
#   'also',
#   'the',
#   'arrangement',
#   'of',
#   'machine.',
#   'i',
#   'do',
#   'not',
#   'know',
#   'where',
#   'is',
#   'bearing#2',
#   'or',
#   '3',
#   'and',
#   'so',
#   'on.',
#   'you',
#   'said',
#   'that',
#   'the',
#   'casing',
#   'have',
#   'done',
#   'bore',
#   'alignment',
#   'due',
#   'to',
#   'center',
#   'of',
#   'bearing',
#   'housing',
#   '2',
#   'and',
#   '3',
#   'is',
#   'not',
#   'coincided.',
#   'how',
#   'about',
#   'the',
#   'alignment',
#   'result',
#   'and',
#   'how',
#   'about',
#   'the',
#   'rotor',
#   'center',
#   'position',
#   'check',
#   '(done',
#   'at',
#   'some',
#   'hole',
#   'on',
#   'casing).',
#   'how',
#   'about',
#   'labyrinth',
#   'clearance',
#   'at',
#   'both',
#   'side',
#   'of',
#   'bearing?',
#   'how',
#   'about',
#   'the',
#   'phase?']]

# %%
def removeStopWordsFunct(x):
    from nltk.corpus import stopwords
    stop_words=set(stopwords.words('english'))
    filteredSentence = [w for w in x if not w in stop_words]
    return filteredSentence

stopwordRDD = wordTokenizeRDD.map(removeStopWordsFunct)

def removePunctuationsFunct(x):
    list_punct=list(string.punctuation)
    filtered = [''.join(c for c in s if c not in list_punct) for s in x] 
    filtered_space = [s for s in filtered if s] #remove empty space 
    return filtered

rmvPunctRDD = stopwordRDD.map(removePunctuationsFunct)

# %%
def lemmatizationFunct(x):
    nltk.download('wordnet')
    lemmatizer = WordNetLemmatizer()
    finalLem = [lemmatizer.lemmatize(s) for s in x]
    return finalLem

lem_wordsRDD = rmvPunctRDD.map(lemmatizationFunct)

# %%
def joinTokensFunct(x):
    joinedTokens_list = []
    x = " ".join(x)
    return x

joinedTokens = lem_wordsRDD.map(joinTokensFunct)

# %%
def VPextractPhraseFunct(x):
    from nltk.corpus import stopwords
    stop_words=set(stopwords.words('english'))    
    
    def leaves(tree):
        #Finds NP (nounphrase) leaf nodes of a chunk tree.
        for subtree in tree.subtrees(filter = lambda t: t.label()=='VP' ):
            yield subtree.leaves()
   
    def get_terms(tree):
        for leaf in leaves(tree):
            term = [w for w,t in leaf if not w in stop_words]
            yield term
    
    sentence_re = r'(?:(?:[A-Z])(?:.[A-Z])+.?)|(?:\w+(?:-\w+)*)|(?:\$?\d+(?:.\d+)?%?)|(?:...|)(?:[][.,;"\'?():-_`])'
    grammar = r"""
    NP: {<DT|JJ|NN.*>+}          # Chunk sequences of DT, JJ, NN
    VP: {<VB.*><NP>|<NP.*><VB.*>} # Chunk verbs and their arguments
    """
    chunker = nltk.RegexpParser(grammar)
    tokens = nltk.regexp_tokenize(x,sentence_re)
    postoks = nltk.tag.pos_tag(tokens) #Part of speech tagging 
    tree = chunker.parse(postoks) #chunking
    terms = get_terms(tree)
    temp_phrases = []
    for term in terms:
        if len(term):
            temp_phrases.append(' '.join(term))
    
    finalPhrase = [w for w in temp_phrases if w] #remove empty lists
    return finalPhrase

def NPextractPhraseFunct(x):
    from nltk.corpus import stopwords
    stop_words=set(stopwords.words('english'))    
    
    def leaves(tree):
        #Finds NP (nounphrase) leaf nodes of a chunk tree.
        for subtree in tree.subtrees(filter = lambda t: t.label()=='NP' ):
            yield subtree.leaves()
   
    def get_terms(tree):
        for leaf in leaves(tree):
            term = [w for w,t in leaf if not w in stop_words]
            yield term
    
    sentence_re = r'(?:(?:[A-Z])(?:.[A-Z])+.?)|(?:\w+(?:-\w+)*)|(?:\$?\d+(?:.\d+)?%?)|(?:...|)(?:[][.,;"\'?():-_`])'
    grammar = r"""
    NBAR: {<NN.*|JJ>*<NN.*>}  # Nouns and Adjectives, terminated with Nouns
    NP: {<NBAR>}
        {<NBAR><IN><NBAR>}  # Above, connected with in/of/etc...
    """
    chunker = nltk.RegexpParser(grammar)
    tokens = nltk.regexp_tokenize(x,sentence_re)
    postoks = nltk.tag.pos_tag(tokens) #Part of speech tagging 
    tree = chunker.parse(postoks) #chunking
    terms = get_terms(tree)
    temp_phrases = []
    for term in terms:
        if len(term):
            temp_phrases.append(' '.join(term))
    
    finalPhrase = [w for w in temp_phrases if w] #remove empty lists
    return finalPhrase

VPextractphraseRDD = joinedTokens.map(VPextractPhraseFunct)
NPextractphraseRDD = joinedTokens.map(NPextractPhraseFunct)

# %%
def sentimentWordsFunct(x):
    analyzer = SentimentIntensityAnalyzer() 
    senti_list_temp = []    
    for i in x:
        y = ''.join(i) 
        vs = analyzer.polarity_scores(y)
        senti_list_temp.append((y, vs))
        senti_list_temp = [w for w in senti_list_temp if w]    
    sentiment_list  = []
    for j in senti_list_temp:
        first = j[0]
        second = j[1]
        for (k,v) in second.items():
            if k == 'compound':
                if v < 0.0:
                    sentiment_list.append((first, "Negative"))
                elif v == 0.0:
                    sentiment_list.append((first, "Neutral"))
                else:
                    sentiment_list.append((first, "Positive"))     
    return sentiment_list

VPsentimentRDD = VPextractphraseRDD.map(sentimentWordsFunct)
NPsentimentRDD = NPextractphraseRDD.map(sentimentWordsFunct)

# %%
VPsentimentRDD.collect()
# Out:
# [[('bearing came', 'Neutral'),
#   ('drive toyo pump vibration showing', 'Neutral'),
#   ('bsf sidebands ftf', 'Neutral'),
#   ('showing much velocity spectrum sure early make call', 'Positive'),
#   ('example bearing', 'Neutral')],
#  [('cent httpswwwschaefflercomremgfailuresusenpdf dave', 'Neutral')],
#  [('bfran21 posted', 'Neutral'),
#   ('bearing came', 'Neutral'),
#   ('drive toyo pump vibration showing', 'Neutral'),
#   ('bsf sidebands ftf', 'Neutral'),
#   ('showing much velocity spectrum sure early make call', 'Positive'),
#   ('example bearing', 'Neutral'),
#   ('smearing sign', 'Neutral'),
#   ('according iso', 'Neutral'),
#   ('resulting poor lubrication', 'Negative'),
#   ('light load', 'Neutral')],
#  [('case mill motor sugar industry bearing', 'Neutral'),
#   ('failing due bearing current fluting mark nde side bearing insulated bearing',
#    'Negative'),
#   ('last failure incident changed', 'Negative'),
#   ('insulated nde insulated', 'Neutral'),
#   ('carbongrounding brush', 'Neutral'),
#   ('end side end cover', 'Neutral'),
#   ('season operating', 'Neutral'),
#   ('month bearing failed', 'Negative'),
#   ('identifying reason', 'Neutral'),
#   ('corrective action thanks regard', 'Positive')],
#  [('post spectrumhow current pass shaft bearing avoid itfirsttime',
#    'Negative'),
#   ('seeing problem', 'Negative')],
#  [('failing current first thing upgrade ceramic', 'Negative'),
#   ('rolling element', 'Neutral'),
#   ('bearing possible hassle sure fix application', 'Positive'),
#   ('complete steel bearing', 'Neutral'),
#   ('running life', 'Neutral'),
#   ('luck shaft', 'Positive'),
#   ('grounding brush photo', 'Neutral'),
#   ('bearing race sure current damage', 'Negative')],
#  [('consider conductive grease kluber electric graphite grease', 'Neutral'),
#   ('allows current', 'Neutral'),
#   ('go ground', 'Neutral'),
#   ('following interesting httpecmwebcommotorsdiagntorbearingcurrents',
#    'Positive')],
#  [('thank chuck looking', 'Positive')],
#  [],
#  [('hi abhi03 sorry delay traveling', 'Negative'),
#   ('clear bearing', 'Positive'),
#   ('issue current arcing', 'Neutral'),
#   ('ceramic rolling element bearing', 'Neutral'),
#   ('pump oem use work switched', 'Neutral'),
#   ('ceramic rolling element standard considering', 'Neutral')],
#  [('thansk chuck', 'Neutral')],
#  [('add important make', 'Positive'),
#   ('sure insulating', 'Positive'),
#   ('motor bearing', 'Neutral'),
#   ('driven equipment insulated', 'Neutral'),
#   ('motor company instance preventing', 'Negative'),
#   ('motor rebuild caused', 'Neutral'),
#   ('gearbox rebuild coupling', 'Neutral'),
#   ('metal grid current went', 'Neutral')],
#  [('add additional experiencemotor', 'Neutral'),
#   ('phase insulated', 'Neutral'),
#   ('shaft end intermittent duty megged', 'Neutral'),
#   ('bare shaft insulating', 'Neutral'),
#   ('material end shaft grounding', 'Neutral'),
#   ('ring bearing oil grease', 'Neutral'),
#   ('electrical fluting suspected', 'Negative'),
#   ('volt rotating', 'Neutral'),
#   ('determine fault lie put', 'Negative'),
#   ('plan place fault determinedverified', 'Negative'),
#   ('inductance cable', 'Neutral'),
#   ('lying next', 'Negative'),
#   ('another cable tray earth ground weak broken rustdirt machine foundation allowing',
#    'Negative'),
#   ('good ground name ran', 'Positive')],
#  [('good point experienced', 'Positive'),
#   ('varying degree', 'Neutral'),
#   ('extruder motor installed couple ground ring', 'Neutral'),
#   ('rep ring', 'Neutral'),
#   ('manufacturer test motor showed', 'Neutral'),
#   ('problem due bad ground inspection found', 'Negative'),
#   ('ground lug tight', 'Neutral'),
#   ('shaft voltage motor', 'Neutral'),
#   ('ring check voltage level every', 'Neutral'),
#   ('month shaft cleaned', 'Neutral'),
#   ('motor ring mounted', 'Neutral'),
#   ('worry grease pushing', 'Negative')],
#  [('first time blog see', 'Neutral'),
#   ('posting year old', 'Neutral'),
#   ('reviewed picture agree', 'Positive'),
#   ('induced bearing failure incidence rate bearing failure', 'Negative'),
#   ('motor least', 'Neutral'),
#   ('year continues', 'Neutral'),
#   ('wellaccepted pervasive problem', 'Negative'),
#   ('plague operation run', 'Neutral'),
#   ('following information', 'Neutral'),
#   ('based longterm field lab study', 'Neutral'),
#   ('capacitive discharge bearing', 'Neutral'),
#   ('local event caused', 'Neutral'),
#   ('vfd gated', 'Neutral'),
#   ('mechanism switching', 'Neutral'),
#   ('vfd brand altering', 'Neutral'),
#   ('carrier frequency installing', 'Neutral'),
#   ('wiring shunt conductive grease', 'Neutral'),
#   ('fix phenomenon shaft grounding', 'Neutral'),
#   ('device known', 'Neutral'),
#   ('eliminate capacitive discharge', 'Neutral'),
#   ('circulating current present', 'Neutral'),
#   ('framed motor inherent motor different capacitive coupling', 'Neutral'),
#   ('field research shown', 'Neutral'),
#   ('rpm susceptible circulating', 'Neutral'),
#   ('current incident rate circulating', 'Neutral'),
#   ('motor parameter described', 'Neutral'),
#   ('insulated bearing take', 'Neutral'),
#   ('care circulating', 'Positive'),
#   ('take bearing', 'Neutral'),
#   ('connected equipment typical setup deal', 'Neutral'),
#   ('circulating current', 'Neutral'),
#   ('provide shaft', 'Neutral'),
#   ('grounding end motor use', 'Neutral'),
#   ('bearing nondrive end drive end shaft', 'Neutral'),
#   ('grounding system break current loop', 'Neutral'),
#   ('shaft grounding', 'Neutral'),
#   ('confusing different available product market', 'Negative'),
#   ('following key principal cannot', 'Neutral'),
#   ('researching shaft', 'Neutral'),
#   ('grounding product', 'Neutral'),
#   ('concept question forefront mind researching', 'Neutral'),
#   ('shaft grounding', 'Neutral'),
#   ('option grounding', 'Neutral'),
#   ('better competitor', 'Positive'),
#   ('grounding voltagecurrent', 'Neutral'),
#   ('bearing shaft', 'Neutral'),
#   ('grounding system', 'Neutral'),
#   ('box shaft grounding', 'Neutral'),
#   ('voltage threshold prevent current flow dielectric bearing', 'Positive'),
#   ('shaft grounding', 'Neutral'),
#   ('system cannot maintain', 'Neutral'),
#   ('longterm voltage known', 'Neutral'),
#   ('major manufacturer shaft grounding', 'Neutral'),
#   ('ring sgrs', 'Neutral'),
#   ('asked question', 'Neutral'),
#   ('know grounding system working', 'Neutral'),
#   ('response shaft voltage reading', 'Neutral')],
#  [('month observed', 'Neutral'),
#   ('high frequency component motor nde brg pa fan motor nde got', 'Positive'),
#   ('sound bearing', 'Neutral'),
#   ('increasedwe using', 'Neutral'),
#   ('spectrum showed', 'Neutral'),
#   ('high frequency component', 'Neutral'),
#   ('day increased', 'Positive'),
#   ('overall vibration increased', 'Positive'),
#   ('sound increased', 'Positive'),
#   ('motor replaced', 'Neutral'),
#   ('posting nde side', 'Neutral'),
#   ('please confirm bearing defect', 'Negative')],
#  [],
#  [('thats textbook', 'Neutral'),
#   ('fluting many good discussion year httpswwwmaintenanceorgtop6320234777420702863',
#    'Positive')],
#  [('first time blog see', 'Neutral'),
#   ('posting couple year old', 'Neutral'),
#   ('reviewed picture agree', 'Positive'),
#   ('induced bearing failure incidence rate bearing failure', 'Negative'),
#   ('motor least', 'Neutral'),
#   ('year continues', 'Neutral'),
#   ('wellaccepted pervasive problem', 'Negative'),
#   ('plague operation run', 'Neutral'),
#   ('following information', 'Neutral'),
#   ('based longterm field lab study', 'Neutral'),
#   ('capacitive discharge bearing', 'Neutral'),
#   ('local event caused', 'Neutral'),
#   ('vfd gated', 'Neutral'),
#   ('mechanism switching', 'Neutral'),
#   ('vfd brand altering', 'Neutral'),
#   ('carrier frequency installing', 'Neutral'),
#   ('wiring shunt conductive grease', 'Neutral'),
#   ('fix phenomenon shaft grounding', 'Neutral'),
#   ('device known', 'Neutral'),
#   ('eliminate capacitive discharge', 'Neutral'),
#   ('circulating current present', 'Neutral'),
#   ('framed motor inherent motor different capacitive coupling', 'Neutral'),
#   ('field research shown', 'Neutral'),
#   ('rpm susceptible circulating', 'Neutral'),
#   ('current incident rate circulating', 'Neutral'),
#   ('motor parameter described', 'Neutral'),
#   ('insulated bearing take', 'Neutral'),
#   ('care circulating', 'Positive'),
#   ('take bearing', 'Neutral'),
#   ('connected equipment typical setup deal', 'Neutral'),
#   ('circulating current', 'Neutral'),
#   ('provide shaft', 'Neutral'),
#   ('grounding end motor use', 'Neutral'),
#   ('bearing nondrive end drive end shaft', 'Neutral'),
#   ('grounding system break current loop', 'Neutral'),
#   ('shaft grounding', 'Neutral'),
#   ('confusing different available product market', 'Negative'),
#   ('following key principal cannot', 'Neutral'),
#   ('researching shaft', 'Neutral'),
#   ('grounding product', 'Neutral'),
#   ('concept question forefront mind researching', 'Neutral'),
#   ('shaft grounding', 'Neutral'),
#   ('option grounding', 'Neutral'),
#   ('better competitor', 'Positive'),
#   ('grounding voltagecurrent', 'Neutral'),
#   ('bearing shaft', 'Neutral'),
#   ('grounding system', 'Neutral'),
#   ('box shaft grounding', 'Neutral'),
#   ('voltage threshold prevent current flow dielectric bearing', 'Positive'),
#   ('shaft grounding', 'Neutral'),
#   ('system cannot maintain', 'Neutral'),
#   ('longterm voltage known', 'Neutral'),
#   ('major manufacturer shaft grounding', 'Neutral'),
#   ('ring sgrs', 'Neutral'),
#   ('asked question', 'Neutral'),
#   ('know grounding system working', 'Neutral'),
#   ('response shaft voltage reading', 'Neutral')],
#  [('fire incident happened', 'Negative'),
#   ('gt side due lube oil leakage either internal external confirmed',
#    'Positive'),
#   ('material loss found', 'Negative'),
#   ('bearing3 see attached', 'Neutral'),
#   ('coke tar', 'Neutral'),
#   ('found lp bucket relevant pic gt crossection dwg', 'Positive'),
#   ('attached question', 'Neutral'),
#   ('whatâ origin lube oil leakage external internal split bearing', 'Neutral'),
#   ('part brg3', 'Neutral'),
#   ('pic attached', 'Neutral'),
#   ('coke tar formed', 'Neutral'),
#   ('lp bucket pic attached', 'Neutral')],
#  [('pic failed', 'Negative')],
#  [('leakage oil happen', 'Neutral'),
#   ('checked oil drain piping', 'Neutral'),
#   ('buffer air supplied', 'Neutral'),
#   ('checked', 'Neutral'),
#   ('checked bearing temp', 'Neutral'),
#   ('increased vibration fire', 'Negative'),
#   ('happen moment gt', 'Positive'),
#   ('think oil leakage', 'Neutral'),
#   ('happen internal', 'Neutral'),
#   ('external believe', 'Neutral'),
#   ('someone seen', 'Neutral'),
#   ('announced bearing look', 'Neutral'),
#   ('running high temp oil high temperature', 'Neutral')],
#  [('posted experience frame', 'Neutral'),
#   ('leakage oil happen', 'Neutral'),
#   ('bearing bearing checked', 'Neutral'),
#   ('bearing3 found', 'Neutral'),
#   ('material lost', 'Negative'),
#   ('bearing found', 'Neutral'),
#   ('checked oil drain piping', 'Neutral'),
#   ('plugstuck yes checked', 'Positive'),
#   ('obstruction plugging', 'Neutral'),
#   ('buffer air supplied', 'Neutral'),
#   ('checked', 'Neutral'),
#   ('seal air taken', 'Neutral'),
#   ('stage axial compressor air supply line checked', 'Neutral'),
#   ('oil vapour system please', 'Positive'),
#   ('elaborate', 'Neutral'),
#   ('checked bearing temp', 'Neutral'),
#   ('increased vibration review fire happen moment gt', 'Positive'),
#   ('think oil leakage', 'Neutral'),
#   ('happen internal', 'Neutral'),
#   ('external believe', 'Neutral'),
#   ('someone seen', 'Neutral'),
#   ('announced fire smoke', 'Negative'),
#   ('observed exhaust duct gt', 'Negative'),
#   ('gt enclosure opened', 'Positive'),
#   ('fire seen', 'Negative'),
#   ('pump shutdown fire', 'Negative'),
#   ('removed lo pump', 'Neutral'),
#   ('fire happened', 'Negative'),
#   ('lo pump shutdown fire removed', 'Negative'),
#   ('mystery oil leaked', 'Negative'),
#   ('fire caught lo penetrated', 'Negative'),
#   ('lp rotor bucket formed', 'Neutral'),
#   ('turbine pressure bearing', 'Negative'),
#   ('running high temp oil high temperature', 'Neutral'),
#   ('form coke bearing3 damage look', 'Negative'),
#   ('secondary damage due fire dry running', 'Negative'),
#   ('lo pump stopped', 'Negative'),
#   ('fire happened', 'Negative')],
#  [('tripped due breakage belt', 'Neutral'),
#   ('increase enclosure', 'Positive'),
#   ('babbitt white metal lead bearing failure sure u recognize bearing pic melted',
#    'Negative'),
#   ('running stationary', 'Neutral'),
#   ('melted due high lo temp sure', 'Positive')],
#  [('possible shaft hot due fire make', 'Negative'),
#   ('picture take', 'Neutral'),
#   ('event sequence see', 'Neutral'),
#   ('event time focus', 'Neutral'),
#   ('oil system clearance think', 'Neutral')],
#  [('inspection brass oil seal found', 'Neutral'),
#   ('leak brg4', 'Negative'),
#   ('got fire question bearing4', 'Negative'),
#   ('fire location melted', 'Negative'),
#   ('fire traveled', 'Negative'),
#   ('brg4 towards brg3 know', 'Neutral'),
#   ('turbine section pressure brg3', 'Negative')],
#  [('siemens sgt', 'Neutral'),
#   ('mw gas turbine generator starting', 'Neutral'),
#   ('machine heavy vibration observed', 'Neutral'),
#   ('rpm high vibration vibration tripping', 'Neutral'),
#   ('trial taken', 'Neutral'),
#   ('machine neglecting', 'Negative'),
#   ('vibration opening', 'Neutral'),
#   ('machine cold end bearing found', 'Neutral'),
#   ('damage photograph attached', 'Negative')],
#  [('find root cause vibration spectrum orbit plot shaft center lone data please post',
#    'Positive')],
#  [('pawannlng posted', 'Neutral'),
#   ('siemens sgt', 'Neutral'),
#   ('mw gas turbine generator starting', 'Neutral'),
#   ('machine heavy vibration observed', 'Neutral'),
#   ('rpm high vibration vibration tripping', 'Neutral'),
#   ('trial taken', 'Neutral'),
#   ('machine neglecting', 'Negative'),
#   ('vibration opening', 'Neutral'),
#   ('machine cold end bearing found', 'Neutral'),
#   ('damage photograph attached', 'Negative'),
#   ('probable reason bearing failure hi pawannlng need', 'Negative'),
#   ('shaft centerline sequence orbit time signal bode polar possible last time taken',
#    'Neutral')],
#  [('dear sir oil analysis done', 'Positive'),
#   ('report normal attaching', 'Neutral')],
#  [('referring diagnostic plot', 'Neutral'),
#   ('think difficult pin', 'Negative'),
#   ('point root cause failure fluid film', 'Negative'),
#   ('tilting pad', 'Neutral'),
#   ('bearing need refer plot', 'Neutral'),
#   ('give clear conclusion opinion', 'Positive'),
#   ('practicing vibration analyst type', 'Neutral'),
#   ('bearing hydro machine type bearing', 'Neutral'),
#   ('used sherub', 'Neutral')],
#  [('dear pawannlng possible cause', 'Positive'),
#   ('low lub oil pressure bearing', 'Negative'),
#   ('preload bearing', 'Neutral'),
#   ('internal external rule last possible cause using', 'Neutral'),
#   ('technology rotating', 'Neutral'),
#   ('guy said', 'Neutral')],
#  [('check attached bearing failure picture bearing', 'Negative'),
#   ('hour replacement equipment centrifugal pumpflowserev cpx water service bearing',
#    'Neutral'),
#   ('c3nde bearing failed', 'Negative'),
#   ('c3 oil lubricated', 'Neutral'),
#   ('running rpm', 'Neutral'),
#   ('previous bearing', 'Neutral'),
#   ('reason failure', 'Negative'),
#   ('axialradial load dirt oil bearing', 'Negative'),
#   ('manufacturing defect brief answer apprenticed', 'Negative'),
#   ('note double raw angular contact ball bearing metal cage cage removed',
#    'Neutral')],
#  [('indicating excessive axial', 'Neutral'),
#   ('loading reason indicate presence excessive heat possible lubricant correct incorrect amount',
#    'Neutral'),
#   ('indicate excessive heat manufacturing defect anything related bearing',
#    'Negative'),
#   ('cocked shaft', 'Neutral'),
#   ('journal find', 'Neutral')],
#  [('posted bearing', 'Neutral'),
#   ('indicating excessive axial', 'Neutral'),
#   ('loading reason indicate presence excessive heat possible lubricant correct incorrect amount',
#    'Neutral'),
#   ('indicate excessive heat manufacturing defect anything related bearing',
#    'Negative'),
#   ('cocked shaft', 'Neutral'),
#   ('journal find', 'Neutral'),
#   ('reason axial loading find problem hey thanks reply', 'Positive'),
#   ('think doubt', 'Negative'),
#   ('right spacer bearinghousing', 'Neutral'),
#   ('time thought', 'Neutral'),
#   ('occurred due', 'Neutral'),
#   ('thank clarifying', 'Positive')],
#  [('hi friend', 'Positive'),
#   ('ht motor found', 'Neutral'),
#   ('spectrum yesterday inspected', 'Neutral'),
#   ('found inner race crackedbut history equipment', 'Neutral'),
#   ('breakdown inner race problemduring', 'Neutral'),
#   ('first time inner race dent second time inner race got', 'Neutral'),
#   ('seized equipment detail motor rpm1489 motor kw1600 nde bearingnu',
#    'Neutral'),
#   ('applicationcement grinding', 'Neutral'),
#   ('cause repetitive inner race damage thanks advance', 'Negative')],
#  [('many month previous failing', 'Negative'),
#   ('inner race wa monitoring device scheduled', 'Neutral'),
#   ('monitoring previous experience get inner race failure bearing',
#    'Negative'),
#   ('fit clearance achieve', 'Positive')],
#  [('hi rg', 'Neutral')],
#  [('much amount impacting', 'Neutral')],
#  [('inner race spun shaft get', 'Neutral')],
#  [('measure bearing', 'Neutral'), ('way sized', 'Neutral')],
#  [('vidya sagar posted', 'Neutral'),
#   ('failure problem due load im', 'Negative'),
#   ('curious sudden failure failure developed', 'Negative'),
#   ('see generate', 'Neutral')],
#  [('dear issue high vibration brg', 'Positive'),
#   ('finish major inspection unit start', 'Neutral'),
#   ('rpm vibration brg', 'Neutral'),
#   ('mm unit loaded', 'Neutral'),
#   ('full load vibration reach', 'Positive'),
#   ('mm fluctuating', 'Neutral'),
#   ('mm mi inspection made', 'Neutral'),
#   ('casing alignment', 'Neutral'),
#   ('recommended manufacturer ge open unit', 'Positive'),
#   ('damage upper haif brg', 'Negative'),
#   ('haif oval aft compressor casing', 'Neutral'),
#   ('open unit vibration brg', 'Neutral'),
#   ('bearing replaced', 'Neutral'),
#   ('please advice', 'Positive'),
#   ('cause vibration note vibration brg', 'Neutral'),
#   ('smooth exceed', 'Neutral')],
#  [('posted dear issue high vibration', 'Positive'),
#   ('finish major inspection unit start', 'Neutral'),
#   ('rpm vibration brg', 'Neutral'),
#   ('mm unit loaded', 'Neutral'),
#   ('full load vibration reach', 'Positive'),
#   ('mm fluctuating', 'Neutral'),
#   ('mm mi inspection made', 'Neutral'),
#   ('casing alignment', 'Neutral'),
#   ('recommended manufacturer ge open unit', 'Positive'),
#   ('damage upper haif brg', 'Negative'),
#   ('haif oval aft compressor casing', 'Neutral'),
#   ('open unit vibration brg', 'Neutral'),
#   ('bearing replaced', 'Neutral'),
#   ('please advice', 'Positive'),
#   ('cause vibration note vibration brg', 'Neutral'),
#   ('smooth exceed', 'Neutral')],
#  [('think give u data', 'Neutral'),
#   ('apht trend waterfall scl orbit anyfor review', 'Neutral'),
#   ('arrangement machine know', 'Neutral'),
#   ('done bore alignment due center', 'Negative'),
#   ('bearing housing', 'Neutral'),
#   ('coincided alignment result rotor center position', 'Neutral'),
#   ('done hole', 'Neutral'),
#   ('casing labyrinth clearance side bearing phase', 'Neutral')]]

# %%
NPsentimentRDD.collect()
# Out:
# [[('bearing', 'Neutral'),
#   ('drive toyo pump vibration', 'Neutral'),
#   ('bsf sidebands', 'Neutral'),
#   ('gse spectrum show', 'Neutral'),
#   ('hesitant make call reason', 'Negative'),
#   ('much velocity spectrum sure early make call', 'Positive'),
#   ('example', 'Neutral')],
#  [('contaminant lubrication', 'Neutral'),
#   ('cent httpswwwschaefflercomremgfailuresusenpdf', 'Neutral')],
#  [('bfran21', 'Neutral'),
#   ('bearing', 'Neutral'),
#   ('drive toyo pump vibration', 'Neutral'),
#   ('bsf sidebands', 'Neutral'),
#   ('gse spectrum show', 'Neutral'),
#   ('hesitant make call reason', 'Negative'),
#   ('much velocity spectrum sure early make call', 'Positive'),
#   ('example', 'Neutral'),
#   ('sign', 'Neutral'),
#   ('poor lubrication', 'Negative'),
#   ('load', 'Neutral')],
#  [('dear friend', 'Positive'),
#   ('case mill motor sugar industry', 'Neutral'),
#   ('due bearing current fluting mark nde side bearing insulated bearing',
#    'Neutral'),
#   ('last failure incident', 'Negative'),
#   ('bearing', 'Neutral'),
#   ('insulated nde', 'Neutral'),
#   ('brush', 'Neutral'),
#   ('side end cover', 'Neutral'),
#   ('season', 'Neutral'),
#   ('month bearing', 'Neutral'),
#   ('reason', 'Neutral'),
#   ('corrective action thanks', 'Positive'),
#   ('abhijit', 'Neutral')],
#  [('spectrumhow current pass shaft bearing avoid itfirsttime', 'Negative'),
#   ('problem', 'Negative')],
#  [('current first thing', 'Neutral'),
#   ('element', 'Neutral'),
#   ('possible hassle sure fix application', 'Positive'),
#   ('complete steel', 'Neutral'),
#   ('bonus hybrid steel ceramic bearing', 'Positive'),
#   ('life', 'Neutral'),
#   ('brush photo', 'Neutral'),
#   ('race sure current damage', 'Negative')],
#  [('conductive grease kluber electric graphite grease', 'Neutral'),
#   ('ground', 'Neutral'),
#   ('httpwwwvibescorpcapdfklricbe44152enpdf', 'Neutral'),
#   ('interesting httpecmwebcommotorsdiagntorbearingcurrents', 'Positive')],
#  [('thank chuck', 'Positive'), ('solution current bearing', 'Positive')],
#  [('thaank', 'Neutral')],
#  [('hi abhi03 sorry delay', 'Negative'),
#   ('issue', 'Neutral'),
#   ('photo', 'Neutral'),
#   ('ceramic rolling element', 'Neutral'),
#   ('pump oem use work', 'Neutral'),
#   ('ceramic rolling element standard', 'Neutral'),
#   ('move industry favor vfd solution use vfd increase stray current cause problem',
#    'Positive')],
#  [('thansk', 'Neutral')],
#  [('id', 'Neutral'),
#   ('add', 'Neutral'),
#   ('motor', 'Neutral'),
#   ('driven equipment', 'Neutral'),
#   ('motor company instance', 'Neutral'),
#   ('motor rebuild', 'Neutral'),
#   ('gearbox rebuild', 'Neutral'),
#   ('metal', 'Neutral'),
#   ('gearbox bearing', 'Neutral')],
#  [('additional experiencemotor', 'Neutral'),
#   ('phase', 'Neutral'),
#   ('shaft end intermittent duty', 'Neutral'),
#   ('bare shaft', 'Neutral'),
#   ('material end shaft', 'Neutral'),
#   ('bearing oil grease', 'Neutral'),
#   ('electrical fluting', 'Neutral'),
#   ('root cause cable vfd motor', 'Neutral'),
#   ('shaft ground', 'Neutral'),
#   ('measuretest', 'Neutral'),
#   ('determine fault lie', 'Negative'),
#   ('plan place fault', 'Negative'),
#   ('cable', 'Neutral'),
#   ('cable tray earth ground weak broken rustdirt machine foundation',
#    'Negative'),
#   ('good ground name', 'Positive'),
#   ('past dave', 'Neutral')],
#  [('good point', 'Positive'),
#   ('extruder motor installed couple ground', 'Neutral'),
#   ('manufacturer test motor', 'Neutral'),
#   ('problem due bad ground inspection', 'Negative'),
#   ('ground lug', 'Neutral'),
#   ('fix', 'Neutral'),
#   ('voltage motor', 'Neutral'),
#   ('check voltage level', 'Neutral'),
#   ('month shaft', 'Neutral'),
#   ('due dirty environment', 'Negative'),
#   ('motor ring', 'Neutral'),
#   ('worry grease', 'Negative'),
#   ('bearing', 'Neutral')],
#  [('first time blog', 'Neutral'),
#   ('year', 'Neutral'),
#   ('picture', 'Neutral'),
#   ('bearing failure incidence rate bearing failure', 'Negative'),
#   ('motor', 'Neutral'),
#   ('year', 'Neutral'),
#   ('pervasive problem', 'Negative'),
#   ('plague operation', 'Neutral'),
#   ('information', 'Neutral'),
#   ('longterm field lab study', 'Neutral'),
#   ('year', 'Neutral'),
#   ('capacitive discharge', 'Neutral'),
#   ('local event', 'Neutral'),
#   ('vfd', 'Neutral'),
#   ('mechanism', 'Neutral'),
#   ('vfd brand', 'Neutral'),
#   ('carrier frequency', 'Neutral'),
#   ('induction', 'Neutral'),
#   ('shunt conductive grease', 'Neutral'),
#   ('fix phenomenon shaft', 'Neutral'),
#   ('device', 'Neutral'),
#   ('way', 'Neutral'),
#   ('capacitive discharge', 'Neutral'),
#   ('motor inherent motor different capacitive coupling', 'Neutral'),
#   ('field research', 'Neutral'),
#   ('motor', 'Neutral'),
#   ('rpm', 'Neutral'),
#   ('motor', 'Neutral'),
#   ('rpm', 'Neutral'),
#   ('current incident rate', 'Neutral'),
#   ('motor parameter', 'Neutral'),
#   ('insulated bearing', 'Neutral'),
#   ('care', 'Positive'),
#   ('current current find', 'Neutral'),
#   ('bearing', 'Neutral'),
#   ('equipment typical setup deal', 'Neutral'),
#   ('shaft', 'Neutral'),
#   ('end motor use', 'Neutral'),
#   ('nondrive end drive end shaft', 'Neutral'),
#   ('system break current loop', 'Neutral'),
#   ('shaft', 'Neutral'),
#   ('device', 'Neutral'),
#   ('different available product market', 'Neutral'),
#   ('key principal cannot', 'Neutral'),
#   ('shaft', 'Neutral'),
#   ('product', 'Neutral'),
#   ('concept question forefront mind', 'Neutral'),
#   ('shaft', 'Neutral'),
#   ('option', 'Neutral'),
#   ('system', 'Neutral'),
#   ('competitor', 'Neutral'),
#   ('shaft', 'Neutral'),
#   ('system', 'Neutral'),
#   ('shaft voltage', 'Neutral'),
#   ('box shaft', 'Neutral'),
#   ('system', 'Neutral'),
#   ('voltage threshold prevent current flow dielectric', 'Positive'),
#   ('grease', 'Neutral'),
#   ('shaft', 'Neutral'),
#   ('system cannot', 'Neutral'),
#   ('longterm voltage', 'Neutral'),
#   ('major manufacturer shaft', 'Neutral'),
#   ('sgrs', 'Neutral'),
#   ('question', 'Neutral'),
#   ('know grounding system', 'Neutral'),
#   ('response shaft voltage', 'Neutral')],
#  [('month', 'Neutral'),
#   ('high frequency component motor nde brg pa fan motor nde', 'Positive'),
#   ('brgs', 'Neutral'),
#   ('sound', 'Neutral'),
#   ('emerson csi', 'Neutral'),
#   ('spectrum', 'Neutral'),
#   ('high frequency', 'Neutral'),
#   ('gse', 'Neutral'),
#   ('day', 'Neutral'),
#   ('overall vibration', 'Neutral'),
#   ('peak peakvue', 'Neutral'),
#   ('hz filter bpfo peak visible peakvue value', 'Positive'),
#   ('sound', 'Neutral'),
#   ('nde brg', 'Neutral'),
#   ('motor', 'Neutral'),
#   ('nde side', 'Neutral'),
#   ('inner race photo', 'Neutral'),
#   ('side nu230 photo', 'Neutral'),
#   ('confirm bearing defect', 'Negative')],
#  [('innner race nu230 brg zoom view', 'Neutral')],
#  [('thats', 'Neutral'),
#   ('many good discussion year httpswwwmaintenanceorgtop6320234777420702863',
#    'Positive')],
#  [('first time blog', 'Neutral'),
#   ('couple year', 'Neutral'),
#   ('picture', 'Neutral'),
#   ('bearing failure incidence rate bearing failure', 'Negative'),
#   ('motor', 'Neutral'),
#   ('year', 'Neutral'),
#   ('pervasive problem', 'Negative'),
#   ('plague operation', 'Neutral'),
#   ('information', 'Neutral'),
#   ('longterm field lab study', 'Neutral'),
#   ('year', 'Neutral'),
#   ('capacitive discharge', 'Neutral'),
#   ('local event', 'Neutral'),
#   ('vfd', 'Neutral'),
#   ('mechanism', 'Neutral'),
#   ('vfd brand', 'Neutral'),
#   ('carrier frequency', 'Neutral'),
#   ('induction', 'Neutral'),
#   ('shunt conductive grease', 'Neutral'),
#   ('fix phenomenon shaft', 'Neutral'),
#   ('device', 'Neutral'),
#   ('way', 'Neutral'),
#   ('capacitive discharge', 'Neutral'),
#   ('motor inherent motor different capacitive coupling', 'Neutral'),
#   ('field research', 'Neutral'),
#   ('motor', 'Neutral'),
#   ('rpm', 'Neutral'),
#   ('motor', 'Neutral'),
#   ('rpm', 'Neutral'),
#   ('current incident rate', 'Neutral'),
#   ('motor parameter', 'Neutral'),
#   ('insulated bearing', 'Neutral'),
#   ('care', 'Positive'),
#   ('current current find', 'Neutral'),
#   ('bearing', 'Neutral'),
#   ('equipment typical setup deal', 'Neutral'),
#   ('shaft', 'Neutral'),
#   ('end motor use', 'Neutral'),
#   ('nondrive end drive end shaft', 'Neutral'),
#   ('system break current loop', 'Neutral'),
#   ('shaft', 'Neutral'),
#   ('device', 'Neutral'),
#   ('different available product market', 'Neutral'),
#   ('key principal cannot', 'Neutral'),
#   ('shaft', 'Neutral'),
#   ('product', 'Neutral'),
#   ('concept question forefront mind', 'Neutral'),
#   ('shaft', 'Neutral'),
#   ('option', 'Neutral'),
#   ('system', 'Neutral'),
#   ('competitor', 'Neutral'),
#   ('shaft', 'Neutral'),
#   ('system', 'Neutral'),
#   ('shaft voltage', 'Neutral'),
#   ('box shaft', 'Neutral'),
#   ('system', 'Neutral'),
#   ('voltage threshold prevent current flow dielectric', 'Positive'),
#   ('grease', 'Neutral'),
#   ('shaft', 'Neutral'),
#   ('system cannot', 'Neutral'),
#   ('longterm voltage', 'Neutral'),
#   ('major manufacturer shaft', 'Neutral'),
#   ('sgrs', 'Neutral'),
#   ('question', 'Neutral'),
#   ('know grounding system', 'Neutral'),
#   ('response shaft voltage', 'Neutral')],
#  [('machine turbo generator gas turbine ge frame', 'Neutral'),
#   ('fire incident', 'Negative'),
#   ('gt side due lube oil leakage', 'Positive'),
#   ('internal external', 'Neutral'),
#   ('upon inspection', 'Neutral'),
#   ('material loss', 'Negative'),
#   ('bearing3 see', 'Neutral'),
#   ('crossection lp rotor', 'Neutral'),
#   ('tar', 'Neutral'),
#   ('lp bucket relevant pic gt crossection dwg', 'Positive'),
#   ('question', 'Neutral'),
#   ('whatâ origin lube oil leakage external internal split', 'Neutral'),
#   ('housing lube oil supply pipe leakage', 'Neutral'),
#   ('whatâ root cause lube oil leakage', 'Neutral'),
#   ('whatâ root cause babbit material loss', 'Negative'),
#   ('part', 'Neutral'),
#   ('pic', 'Neutral'),
#   ('coke tar', 'Neutral'),
#   ('lp bucket pic', 'Neutral')],
#  [('pic', 'Neutral'), ('bearing', 'Neutral')],
#  [('experience frame', 'Neutral'),
#   ('think check information answer', 'Neutral'),
#   ('leakage oil', 'Neutral'),
#   ('bearing', 'Neutral'),
#   ('bearing', 'Neutral'),
#   ('checked oil drain', 'Neutral'),
#   ('buffer air', 'Neutral'),
#   ('labyrinth seal', 'Neutral'),
#   ('buffer air line', 'Neutral'),
#   ('oil vapour system', 'Neutral'),
#   ('bearing temp', 'Neutral'),
#   ('vibration fire', 'Negative'),
#   ('moment gt', 'Positive'),
#   ('oil leakage', 'Neutral'),
#   ('someone', 'Neutral'),
#   ('bearing look', 'Neutral'),
#   ('high temp oil high temperature', 'Neutral'),
#   ('form coke', 'Neutral')],
#  [('experience frame', 'Neutral'),
#   ('think check information answer', 'Neutral'),
#   ('leakage oil', 'Neutral'),
#   ('bearing', 'Neutral'),
#   ('bearing', 'Neutral'),
#   ('bearing bearing', 'Neutral'),
#   ('bearing3', 'Neutral'),
#   ('bearing', 'Neutral'),
#   ('checked oil drain', 'Neutral'),
#   ('plugstuck yes', 'Positive'),
#   ('obstruction', 'Neutral'),
#   ('buffer air', 'Neutral'),
#   ('labyrinth seal', 'Neutral'),
#   ('buffer air line', 'Neutral'),
#   ('seal air', 'Neutral'),
#   ('stage axial compressor air supply line', 'Neutral'),
#   ('normal required seal air pressure', 'Negative'),
#   ('oil vapour system', 'Neutral'),
#   ('bearing temp', 'Neutral'),
#   ('vibration review fire happen moment gt', 'Negative'),
#   ('oil leakage', 'Neutral'),
#   ('someone', 'Neutral'),
#   ('fire smoke', 'Negative'),
#   ('exhaust duct gt', 'Negative'),
#   ('gt enclosure', 'Positive'),
#   ('fire', 'Negative'),
#   ('shutdown fire', 'Negative'),
#   ('lo pump', 'Neutral'),
#   ('fire', 'Negative'),
#   ('lo pump shutdown fire', 'Negative'),
#   ('fire sure due lo leakage', 'Negative'),
#   ('mystery oil', 'Neutral'),
#   ('fire caught lo', 'Negative'),
#   ('lp rotor bucket', 'Neutral'),
#   ('cokingtar', 'Neutral'),
#   ('lo pressure', 'Negative'),
#   ('turbine pressure', 'Negative'),
#   ('look', 'Neutral'),
#   ('high temp oil high temperature', 'Neutral'),
#   ('form coke bearing3 damage', 'Negative'),
#   ('secondary damage due fire', 'Negative'),
#   ('lp rotor', 'Neutral'),
#   ('lo pump', 'Neutral'),
#   ('fire', 'Negative')],
#  [('ventilation fan', 'Positive'),
#   ('due breakage belt', 'Neutral'),
#   ('enclosure', 'Neutral'),
#   ('babbitt white metal lead bearing failure sure u recognize bearing pic',
#    'Negative'),
#   ('due high lo temp sure', 'Positive')],
#  [('possible shaft hot due fire', 'Negative'),
#   ('babbit overheat', 'Neutral'),
#   ('picture', 'Neutral'),
#   ('event sequence', 'Neutral'),
#   ('event time', 'Neutral'),
#   ('oil system clearance', 'Neutral')],
#  [('inspection brass oil seal', 'Neutral'),
#   ('possibility oil', 'Neutral'),
#   ('fire question bearing4', 'Negative'),
#   ('fire location', 'Negative'),
#   ('fire', 'Negative'),
#   ('brg4 towards brg3', 'Neutral'),
#   ('turbine section pressure', 'Negative'),
#   ('pressure brg4', 'Negative')],
#  [('siemens', 'Neutral'),
#   ('mw gas turbine generator', 'Neutral'),
#   ('machine heavy vibration', 'Neutral'),
#   ('machine tripped', 'Neutral'),
#   ('rpm high vibration vibration', 'Neutral'),
#   ('micron', 'Neutral'),
#   ('trial', 'Neutral'),
#   ('machine', 'Neutral'),
#   ('vibration', 'Neutral'),
#   ('machine cold end bearing', 'Neutral'),
#   ('damage photograph', 'Negative'),
#   ('probable reason bearing failure', 'Negative')],
#  [('dear sir clear bearing continuous rub primary suspect lubrication',
#    'Positive'),
#   ('root cause vibration spectrum orbit plot shaft center lone data please post',
#    'Positive')],
#  [('pawannlng', 'Neutral'),
#   ('siemens', 'Neutral'),
#   ('mw gas turbine generator', 'Neutral'),
#   ('machine heavy vibration', 'Neutral'),
#   ('machine tripped', 'Neutral'),
#   ('rpm high vibration vibration', 'Neutral'),
#   ('micron', 'Neutral'),
#   ('trial', 'Neutral'),
#   ('machine', 'Neutral'),
#   ('vibration', 'Neutral'),
#   ('machine cold end bearing', 'Neutral'),
#   ('damage photograph', 'Negative'),
#   ('probable reason bearing failure hi pawannlng', 'Negative'),
#   ('neglect vibration', 'Negative'),
#   ('share plot', 'Positive'),
#   ('shaft centerline sequence orbit time signal bode polar possible last time',
#    'Neutral'),
#   ('oil analysis', 'Neutral'),
#   ('incident regard rg', 'Neutral')],
#  [('dear sir oil analysis', 'Positive'),
#   ('month', 'Neutral'),
#   ('report', 'Neutral'),
#   ('available vibration plot', 'Neutral')],
#  [('dear pawan', 'Positive'),
#   ('diagnostic plot', 'Neutral'),
#   ('difficult pin', 'Negative'),
#   ('root cause failure fluid film', 'Negative'),
#   ('pad', 'Neutral'),
#   ('need refer plot', 'Neutral'),
#   ('plot', 'Neutral'),
#   ('clear conclusion opinion', 'Positive'),
#   ('vibration analyst type', 'Neutral'),
#   ('hydro machine type bearing', 'Neutral'),
#   ('sherub', 'Neutral')],
#  [('dear pawannlng possible cause', 'Positive'),
#   ('misalignment external misalignment', 'Neutral'),
#   ('bearing housing excentricity internal misalignment', 'Neutral'),
#   ('low lub oil pressure', 'Negative'),
#   ('restriction', 'Negative'),
#   ('line', 'Neutral'),
#   ('radial load', 'Neutral'),
#   ('preload', 'Neutral'),
#   ('internal external rule last possible cause', 'Neutral'),
#   ('technology', 'Neutral'),
#   ('guy', 'Neutral'),
#   ('shaft centerline sequence orbit time signal bode polar possible spectrum etc',
#    'Neutral')],
#  [('attached bearing failure picture bearing', 'Negative'),
#   ('hour replacement equipment centrifugal pumpflowserev cpx water service',
#    'Neutral'),
#   ('c3de skf', 'Neutral'),
#   ('c3nde bearing', 'Neutral'),
#   ('c3 oil', 'Neutral'),
#   ('bearing vg', 'Neutral'),
#   ('rpm', 'Neutral'),
#   ('alignment range', 'Neutral'),
#   ('life', 'Neutral'),
#   ('hour', 'Neutral'),
#   ('reason', 'Neutral'),
#   ('axialradial load dirt oil', 'Negative'),
#   ('manufacturing defect brief answer', 'Negative'),
#   ('note double raw angular contact ball bearing metal cage cage', 'Neutral'),
#   ('taking picture', 'Neutral')],
#  [('reason indicate presence excessive heat possible lubricant correct incorrect amount',
#    'Neutral'),
#   ('excessive heat manufacturing defect anything related bearing', 'Negative'),
#   ('shaft', 'Neutral'),
#   ('reason axial loading find problem', 'Negative')],
#  [('johnny', 'Neutral'),
#   ('bearing', 'Neutral'),
#   ('reason indicate presence excessive heat possible lubricant correct incorrect amount',
#    'Neutral'),
#   ('excessive heat manufacturing defect anything related bearing', 'Negative'),
#   ('shaft', 'Neutral'),
#   ('reason axial loading find problem hey thanks', 'Positive'),
#   ('doubt', 'Negative'),
#   ('right spacer', 'Neutral'),
#   ('axial direction position small portion', 'Neutral'),
#   ('time', 'Neutral'),
#   ('confusion', 'Negative')],
#  [('hi', 'Neutral'),
#   ('ht motor', 'Neutral'),
#   ('inner race defect side band', 'Negative'),
#   ('spectrum yesterday', 'Neutral'),
#   ('inner race crackedbut history equipment', 'Neutral'),
#   ('breakdown inner race', 'Neutral'),
#   ('first time inner race dent second time inner race', 'Neutral'),
#   ('seized equipment detail motor rpm1489 motor kw1600 nde', 'Neutral'),
#   ('applicationcement', 'Neutral'),
#   ('repetitive inner race damage thanks advance', 'Negative')],
#  [('hi', 'Neutral'),
#   ('many month', 'Neutral'),
#   ('inner race wa monitoring device', 'Neutral'),
#   ('monitoring previous experience get inner race failure', 'Negative'),
#   ('fit clearance', 'Positive'),
#   ('regard', 'Neutral')],
#  [('hi', 'Neutral'),
#   ('previous failure', 'Negative'),
#   ('year', 'Neutral'),
#   ('spm instrument condition monitoringdoes fitment clearance cause',
#    'Neutral'),
#   ('failure problem due load', 'Negative')],
#  [('much amount', 'Neutral'),
#   ('happen temperature increase', 'Positive'),
#   ('crack ovehaul inner race spun shaft regard', 'Neutral')],
#  [('rg significant increase temperature', 'Positive'),
#   ('inner race spun shaft', 'Neutral'),
#   ('impact u askingwhether load twf', 'Neutral')],
#  [('measure', 'Neutral'), ('fit shaft', 'Positive'), ('way', 'Neutral')],
#  [('vidya sagar', 'Neutral'),
#   ('previous failure', 'Negative'),
#   ('year', 'Neutral'),
#   ('spm instrument condition monitoringdoes fitment clearance cause',
#    'Neutral'),
#   ('failure problem due load', 'Negative'),
#   ('curious sudden failure failure', 'Negative'),
#   ('doubt data collection', 'Negative'),
#   ('see', 'Neutral'),
#   ('fault regard', 'Negative')],
#  [('dear issue high vibration', 'Positive'),
#   ('finish major inspection unit', 'Neutral'),
#   ('unit', 'Neutral'),
#   ('rpm vibration', 'Neutral'),
#   ('stable exceed', 'Positive'),
#   ('mm unit', 'Neutral'),
#   ('vibration increase brg', 'Positive'),
#   ('full load vibration', 'Neutral'),
#   ('brg', 'Neutral'),
#   ('mm', 'Neutral'),
#   ('mm mi inspection', 'Neutral'),
#   ('alignment', 'Neutral'),
#   ('manufacturer ge open unit', 'Neutral'),
#   ('damage upper haif', 'Negative'),
#   ('damage', 'Negative'),
#   ('haif oval aft compressor', 'Neutral'),
#   ('open unit vibration', 'Neutral'),
#   ('bearing', 'Neutral'),
#   ('vibration', 'Neutral'),
#   ('advice', 'Neutral'),
#   ('cause vibration note vibration', 'Neutral'),
#   ('smooth', 'Neutral'),
#   ('full load thanks advance', 'Positive')],
#  [('ahmad', 'Neutral'),
#   ('dear issue high vibration', 'Positive'),
#   ('finish major inspection unit', 'Neutral'),
#   ('unit', 'Neutral'),
#   ('rpm vibration', 'Neutral'),
#   ('stable exceed', 'Positive'),
#   ('mm unit', 'Neutral'),
#   ('vibration increase brg', 'Positive'),
#   ('full load vibration', 'Neutral'),
#   ('brg', 'Neutral'),
#   ('mm', 'Neutral'),
#   ('mm mi inspection', 'Neutral'),
#   ('alignment', 'Neutral'),
#   ('manufacturer ge open unit', 'Neutral'),
#   ('damage upper haif', 'Negative'),
#   ('damage', 'Negative'),
#   ('haif oval aft compressor', 'Neutral'),
#   ('open unit vibration', 'Neutral'),
#   ('bearing', 'Neutral'),
#   ('vibration', 'Neutral'),
#   ('advice', 'Neutral'),
#   ('cause vibration note vibration', 'Neutral'),
#   ('smooth', 'Neutral'),
#   ('full load thanks advance please help', 'Positive')],
#  [('give u data', 'Neutral'),
#   ('trend waterfall scl orbit anyfor review', 'Neutral'),
#   ('arrangement machine', 'Neutral'),
#   ('bore alignment due center', 'Negative'),
#   ('housing', 'Neutral'),
#   ('alignment result rotor center position', 'Neutral'),
#   ('hole', 'Neutral'),
#   ('labyrinth clearance side bearing phase', 'Neutral')]]

# %%
def extract_by_sentiment(x,sentiment_type):
    target_words = []
    for items in x:
        if len(items)>0:
            if items[len(items)-1]== str(sentiment_type):
                target_words.append(" ".join(items[:len(items)-1]))
    return target_words

neg_sentiments = lambda x: extract_by_sentiment(x, "Negative")
neutral_sentiments = lambda x: extract_by_sentiment(x, "Neutral")
pos_sentiments = lambda x: extract_by_sentiment(x, "Positive")


failModeCauses = VPsentimentRDD.map(neg_sentiments,neutral_sentiments) # Of Verb Phrases
failMode = NPsentimentRDD.map(neg_sentiments,neutral_sentiments) # Of Noun Phrases

# %%
freqDistRDDNeg = failModeCauses.flatMap(lambda x : nltk.FreqDist(x).most_common()).map(lambda x: x).reduceByKey(lambda x,y : x+y).sortBy(lambda x: x[1], ascending = False)

df_fDistNeg = freqDistRDDNeg.toDF() #converting RDD to spark dataframe
df_fDistNeg.createOrReplaceTempView("myTableNeg") 
dfNeg = spark.sql("SELECT _1 AS Keywords, _2 as Frequency from myTableNeg limit 40") #renaming columns 
pandDNeg = dfNeg.toPandas() #converting spark dataframes to pandas dataframes

wordcloudConvertDFNeg = pandDNeg.set_index('Keywords').T.to_dict('records')
wordcloudNeg = WordCloud(width=800, height=500, random_state=21, max_font_size=100, relative_scaling=0.5, colormap='summer').generate_from_frequencies(dict(*wordcloudConvertDFNeg))
plt.figure(figsize=(14, 10))    
plt.imshow(wordcloudNeg, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
freqDistRDDPos = failMode.flatMap(lambda x : nltk.FreqDist(x).most_common()).map(lambda x: x).reduceByKey(lambda x,y : x+y).sortBy(lambda x: x[1], ascending = False)

df_fDistPos = freqDistRDDPos.toDF() #converting RDD to spark dataframe
df_fDistPos.createOrReplaceTempView("myTablePos") 
dfPos = spark.sql("SELECT _1 AS Keywords, _2 as Frequency from myTablePos limit 40") #renaming columns 
pandDPos = dfPos.toPandas() #converting spark dataframes to pandas dataframes

wordcloudConvertDFPos = pandDPos.set_index('Keywords').T.to_dict('records')
wordcloudPos = WordCloud(width=800, height=500, random_state=21, max_font_size=100, relative_scaling=0.5, colormap='summer_r').generate_from_frequencies(dict(*wordcloudConvertDFPos))
plt.figure(figsize=(14, 10))    
plt.imshow(wordcloudPos, interpolation="bilinear")
plt.axis('off')
plt.show()
